# %% [markdown]
# # Task A:
#
# ## MongoDB Data Model
#
# * When developing an application, question really boils down to what are requirements of an application. In most applications there are requirements to :
# > 1. Input data, perform some processing, save the data,retrieve the data and query the data. There may also be a
#     requirement to generate reports on the data.
# > 2. Exchange data between different parts of the system or with external systems.
# * In order to achieve the requirements for Item 1 a method of persisting data is required. Typically if the volume of data is very small and the type of data is simple and does not require extensive search capabilities then a simple file structure may be used. As data becomes more big and complex, which we have as the old techniques have failed to provide the results on time to predict fire, a XML (or even JSON) structure may be used with the data still stored in files. Searching though becomes more problematic. As the volume of data increases and the complexity of searches increases a database is normally selected which provides industry standard methods for data persistence, querying etc. The databases can designed to handle large volumes of data and store,retrieve and search the data quickly and efficiently.
# * In order to achieve the requirements for Item 2 there are various different methods for allowing data interchange between systems including XML, JSON etc.
# * Based on the information given in the data sets, climate data is recorded on a daily basis whereas fire data is recorded on the occurence of a fire on a particular day. So, for one climate data, there can be zero or many fire data.
# * The list of all the entities in hotspot_historic.csv
# > latitude,longitude,datetime,confidence,date,surface_temperature_celcius.
# * The list of all the entities in climate_historic.csv
# > station,date,air_temperature_celcius,relative_humidity,windspeed_knots,max_wind_speed,precipitation
# * There are 2 ways of creating a collection
# > 1. Referencing :-  Where _id field of one document is referenced in another document as a reference. For many use cases in MongoDB, the denormalized data model where related data is stored within a single document is optimal
# > 2. Embedding :- Embed one document in another.
# * Since one to many relationship is a good model design and is using embedding, after the group discussion we decided to go for embedding one document to other.
# * Based on the attributes of two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, the two data sets are linked through date attribute from both data sets. For one date there can be zero or many fire
# * We perform a one to many relationship here, on the date attribute.
# * Since we are merging the two datasets, we append the merged entries to a new attribute called Hotspot in the climate dictionary.
# > {'air_temperature_celcius': 19,
#   'date': '31/12/2016',
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'relative_humidity': 56.8,
#   'station': 948700,
#   'windspeed_knots': 7.9,
#   'Hotspot : [{
#                'confidence': 87,
#                'date': '6/03/2017',
#                'datetime': '2017-03-06T05:06:30',
#                'location': (-34.3795, 141.6331),
#                'surface_temperature_celcius': 62},
#               ]'}
# * There is no second collection in our database, there is just one collection named 'climate' in our database, since the hotspot_historic dataset is merged to the climate historic. We can retrive the hotspot data just like any other attribute, but here our Hotspot is a list of list(attributes of Hotspot_historic).

# %%
# import statements
import pandas as pd
import csv  
import json  
import pymongo
from pymongo import MongoClient
from pprint import pprint

# %%
#reading in the datasets in pandas`
hotspot_historic = pd.read_csv("hotspot_historic.csv")
climate_historic = pd.read_csv("climate_historic.csv")

# %%
#appending to the list hotspot_data
hotspot_data = []
for m,n in hotspot_historic.iterrows():
    hotspot_data.append(list(n.values))
hotspot_data[0][4]
# Out:
# '27/12/2017'

# %%
# creating a list called climate_data and appending value to it 
climate_data = []
for m,n in climate_historic.iterrows():
    climate_data.append(list(n.values))
climate_data[0][1]
# Out:
# '31/12/2016'

# %%
# creating a list of dictionary inside the dictionary
climate_list = []
#reading the climate_data and saving in to the dictionary called hotspot_list
for i in climate_data:
    dic={}
    dic['station']=i[0]
    dic['date']=i[1]
    dic['air_temperature_celcius']=i[2]
    dic['relative_humidity']=i[3]
    dic['windspeed_knots']=i[4]
    dic['max_wind_speed']=i[5]
    dic['precipitation']=i[6]
    #creating the hotspot_list 
    hotspot_list = []
    #rading the hotspot data and saving into the dictionary called dicti 
    for j in hotspot_data:
        if i[1] == j[4]:
            dicti={}
            dicti['location'] = (j[0],j[1])
            dicti['date'] = j[4]
            dicti['datetime'] = j[2]
            dicti['confidence'] = j[3]
            dicti['surface_temperature_celcius'] = j[5]
            #appending the dictionary into the above created dictionary
            hotspot_list.append(dicti)
    #finally creating hotspot as an attribute in the main dictionary
    dic['Hotspot']=hotspot_list
    climate_list.append(dic)
climate_list
# Out:
# [{'station': 948700,
#   'date': '31/12/2016',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 56.8,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '2/01/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 50.7,
#   'windspeed_knots': 9.2,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.02G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '3/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 53.6,
#   'windspeed_knots': 8.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '4/01/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 61.6,
#   'windspeed_knots': 7.7,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '5/01/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 62.3,
#   'windspeed_knots': 7.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '6/01/2017',
#   'air_temperature_celcius': 26,
#   'relative_humidity': 60.8,
#   'windspeed_knots': 6.9,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '7/01/2017',
#   'air_temperature_celcius': 32,
#   'relative_humidity': 54.1,
#   'windspeed_knots': 12.8,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '8/01/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 57.7,
#   'windspeed_knots': 9.9,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '9/01/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 56.3,
#   'windspeed_knots': 5.8,
#   'max_wind_speed': 8.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '10/01/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 57.0,
#   'windspeed_knots': 8.7,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '11/01/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.3,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '12/01/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 56.3,
#   'windspeed_knots': 8.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.08G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '13/01/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 54.1,
#   'windspeed_knots': 11.2,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.31G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '14/01/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 50.4,
#   'windspeed_knots': 11.9,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '15/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 50.8,
#   'windspeed_knots': 5.8,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '16/01/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 55.4,
#   'windspeed_knots': 5.9,
#   'max_wind_speed': 9.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '17/01/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 53.4,
#   'windspeed_knots': 9.9,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '18/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 46.7,
#   'windspeed_knots': 10.0,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '19/01/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 57.2,
#   'windspeed_knots': 8.9,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.98G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '20/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 50.9,
#   'windspeed_knots': 12.9,
#   'max_wind_speed': 21.0,
#   'precipitation': ' 0.03G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '21/01/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 52.5,
#   'windspeed_knots': 6.7,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '22/01/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 59.0,
#   'windspeed_knots': 6.0,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '23/01/2017',
#   'air_temperature_celcius': 25,
#   'relative_humidity': 58.3,
#   'windspeed_knots': 12.2,
#   'max_wind_speed': 22.0,
#   'precipitation': ' 0.04G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '24/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.2,
#   'windspeed_knots': 9.9,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '25/01/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 50.8,
#   'windspeed_knots': 9.0,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '26/01/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.5,
#   'windspeed_knots': 8.8,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '27/01/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 56.1,
#   'windspeed_knots': 6.9,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00A',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '28/01/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 57.0,
#   'windspeed_knots': 7.4,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '29/01/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 58.0,
#   'windspeed_knots': 6.9,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '30/01/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 55.8,
#   'windspeed_knots': 10.5,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '31/01/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.4,
#   'windspeed_knots': 8.1,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '1/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.9,
#   'windspeed_knots': 5.4,
#   'max_wind_speed': 8.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '2/02/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.0,
#   'windspeed_knots': 6.6,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '3/02/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 54.4,
#   'windspeed_knots': 5.7,
#   'max_wind_speed': 9.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '4/02/2017',
#   'air_temperature_celcius': 26,
#   'relative_humidity': 53.7,
#   'windspeed_knots': 8.7,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '5/02/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 64.5,
#   'windspeed_knots': 10.6,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 1.26G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '6/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.1,
#   'windspeed_knots': 9.3,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '7/02/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 57.4,
#   'windspeed_knots': 10.9,
#   'max_wind_speed': 22.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '8/02/2017',
#   'air_temperature_celcius': 31,
#   'relative_humidity': 61.9,
#   'windspeed_knots': 14.1,
#   'max_wind_speed': 23.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '9/02/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 62.7,
#   'windspeed_knots': 7.6,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '10/02/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 60.4,
#   'windspeed_knots': 6.8,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '11/02/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 53.8,
#   'windspeed_knots': 9.2,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.02G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '12/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.3,
#   'windspeed_knots': 14.4,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '13/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 53.6,
#   'windspeed_knots': 12.1,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.16G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '14/02/2017',
#   'air_temperature_celcius': 14,
#   'relative_humidity': 48.5,
#   'windspeed_knots': 7.3,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '15/02/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 53.4,
#   'windspeed_knots': 10.9,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '16/02/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.6,
#   'windspeed_knots': 7.2,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '17/02/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 49.4,
#   'windspeed_knots': 9.3,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '18/02/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 44.6,
#   'windspeed_knots': 9.7,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.02G',
#   'Hotspot': []},
#  {'station': 948700,
#   'date': '19/02/2017',
#   'air_temperature_celcius': 13,
#   'relative_humidity': 48.5,
#   'windspeed_knots': 10.7,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.71G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '20/02/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 49.1,
#   'windspeed_knots': 9.6,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '21/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 51.0,
#   'windspeed_knots': 6.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '22/02/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 49.6,
#   'windspeed_knots': 10.0,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '23/02/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 55.5,
#   'windspeed_knots': 8.9,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '24/02/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 48.3,
#   'windspeed_knots': 9.4,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '25/02/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 52.6,
#   'windspeed_knots': 10.3,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '26/02/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 54.9,
#   'windspeed_knots': 7.4,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '27/02/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 55.6,
#   'windspeed_knots': 5.9,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '28/02/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 54.1,
#   'windspeed_knots': 5.7,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '1/03/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 57.3,
#   'windspeed_knots': 5.4,
#   'max_wind_speed': 9.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '2/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 62.6,
#   'windspeed_knots': 10.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '3/03/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 59.5,
#   'windspeed_knots': 12.4,
#   'max_wind_speed': 21.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '4/03/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 62.0,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '5/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 58.8,
#   'windspeed_knots': 11.5,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '6/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 52.9,
#   'windspeed_knots': 17.0,
#   'max_wind_speed': 21.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-34.3795, 141.6331),
#     'date': '6/03/2017',
#     'datetime': '2017-03-06T05:06:30',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-34.3735, 141.6604),
#     'date': '6/03/2017',
#     'datetime': '2017-03-06T05:06:20',
#     'confidence': 85,
#     'surface_temperature_celcius': 59}]},
#  {'station': 948701,
#   'date': '7/03/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 51.5,
#   'windspeed_knots': 10.2,
#   'max_wind_speed': 20.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.7752, 141.9086),
#     'date': '7/03/2017',
#     'datetime': '2017-03-07T04:16:10',
#     'confidence': 88,
#     'surface_temperature_celcius': 64}]},
#  {'station': 948701,
#   'date': '8/03/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 51.7,
#   'windspeed_knots': 7.2,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.7885, 141.9352),
#     'date': '8/03/2017',
#     'datetime': '2017-03-08T04:51:00',
#     'confidence': 68,
#     'surface_temperature_celcius': 55},
#    {'location': (-38.1031, 142.4797),
#     'date': '8/03/2017',
#     'datetime': '2017-03-08T00:30:30',
#     'confidence': 75,
#     'surface_temperature_celcius': 48}]},
#  {'station': 948701,
#   'date': '9/03/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 53.4,
#   'windspeed_knots': 6.1,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.996, 146.3535),
#     'date': '9/03/2017',
#     'datetime': '2017-03-09T13:23:40',
#     'confidence': 86,
#     'surface_temperature_celcius': 41},
#    {'location': (-37.7171, 147.5866),
#     'date': '9/03/2017',
#     'datetime': '2017-03-09T03:57:00',
#     'confidence': 54,
#     'surface_temperature_celcius': 44},
#    {'location': (-37.7074, 147.5849),
#     'date': '9/03/2017',
#     'datetime': '2017-03-09T03:56:50',
#     'confidence': 78,
#     'surface_temperature_celcius': 55}]},
#  {'station': 948701,
#   'date': '10/03/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 60.2,
#   'windspeed_knots': 6.4,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.223, 147.9431),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:48:40',
#     'confidence': 100,
#     'surface_temperature_celcius': 105},
#    {'location': (-37.2252, 147.9363),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:46:20',
#     'confidence': 100,
#     'surface_temperature_celcius': 109},
#    {'location': (-37.2284, 147.9187),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:45:30',
#     'confidence': 94,
#     'surface_temperature_celcius': 73},
#    {'location': (-37.6572, 142.0703),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:45:30',
#     'confidence': 97,
#     'surface_temperature_celcius': 80},
#    {'location': (-37.6592, 142.058),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:43:50',
#     'confidence': 81,
#     'surface_temperature_celcius': 55},
#    {'location': (-36.2544, 148.0353),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:43:00',
#     'confidence': 55,
#     'surface_temperature_celcius': 42},
#    {'location': (-37.2197, 147.9621),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:42:30',
#     'confidence': 54,
#     'surface_temperature_celcius': 43},
#    {'location': (-37.2128, 147.9308),
#     'date': '10/03/2017',
#     'datetime': '2017-03-10T04:39:00',
#     'confidence': 74,
#     'surface_temperature_celcius': 48}]},
#  {'station': 948701,
#   'date': '11/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 59.7,
#   'windspeed_knots': 8.6,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.01G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '12/03/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 58.1,
#   'windspeed_knots': 5.3,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00G',
#   'Hotspot': [{'location': (-37.4157, 147.0084),
#     'date': '12/03/2017',
#     'datetime': '2017-03-12T04:33:50',
#     'confidence': 94,
#     'surface_temperature_celcius': 105},
#    {'location': (-37.0193, 148.1459),
#     'date': '12/03/2017',
#     'datetime': '2017-03-12T04:29:50',
#     'confidence': 84,
#     'surface_temperature_celcius': 71},
#    {'location': (-37.4229, 147.02700000000002),
#     'date': '12/03/2017',
#     'datetime': '2017-03-12T04:28:20',
#     'confidence': 100,
#     'surface_temperature_celcius': 99},
#    {'location': (-37.0055, 148.1582),
#     'date': '12/03/2017',
#     'datetime': '2017-03-12T04:28:00',
#     'confidence': 80,
#     'surface_temperature_celcius': 68},
#    {'location': (-37.4128, 147.0242),
#     'date': '12/03/2017',
#     'datetime': '2017-03-12T04:27:20',
#     'confidence': 85,
#     'surface_temperature_celcius': 98}]},
#  {'station': 948701,
#   'date': '13/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 62.2,
#   'windspeed_knots': 7.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.0286, 148.155),
#     'date': '13/03/2017',
#     'datetime': '2017-03-13T23:58:50',
#     'confidence': 56,
#     'surface_temperature_celcius': 42},
#    {'location': (-37.0316, 148.1519),
#     'date': '13/03/2017',
#     'datetime': '2017-03-13T12:57:00',
#     'confidence': 52,
#     'surface_temperature_celcius': 35}]},
#  {'station': 948701,
#   'date': '14/03/2017',
#   'air_temperature_celcius': 25,
#   'relative_humidity': 58.3,
#   'windspeed_knots': 7.1,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-34.357, 141.5361),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:24:40',
#     'confidence': 90,
#     'surface_temperature_celcius': 67},
#    {'location': (-34.3539, 141.5547),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:22:20',
#     'confidence': 93,
#     'surface_temperature_celcius': 72},
#    {'location': (-36.9939, 148.2244),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:20:50',
#     'confidence': 90,
#     'surface_temperature_celcius': 68},
#    {'location': (-36.998000000000005, 148.1994),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:19:30',
#     'confidence': 73,
#     'surface_temperature_celcius': 48},
#    {'location': (-36.9959, 148.2118),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:16:30',
#     'confidence': 95,
#     'surface_temperature_celcius': 75},
#    {'location': (-34.3654, 141.543),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:16:20',
#     'confidence': 89,
#     'surface_temperature_celcius': 65},
#    {'location': (-37.0228, 148.1996),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:14:40',
#     'confidence': 73,
#     'surface_temperature_celcius': 52},
#    {'location': (-34.3539, 141.5629),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:14:40',
#     'confidence': 81,
#     'surface_temperature_celcius': 55},
#    {'location': (-34.3554, 141.5413),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:14:30',
#     'confidence': 96,
#     'surface_temperature_celcius': 79},
#    {'location': (-34.3555, 141.5495),
#     'date': '14/03/2017',
#     'datetime': '2017-03-14T04:14:30',
#     'confidence': 94,
#     'surface_temperature_celcius': 75}]},
#  {'station': 948701,
#   'date': '15/03/2017',
#   'air_temperature_celcius': 28,
#   'relative_humidity': 58.4,
#   'windspeed_knots': 11.9,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.04G',
#   'Hotspot': [{'location': (-37.4108, 147.0196),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T05:02:00',
#     'confidence': 76,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.4058, 147.0117),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T04:59:10',
#     'confidence': 74,
#     'surface_temperature_celcius': 48},
#    {'location': (-37.4075, 147.0233),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T00:42:50',
#     'confidence': 52,
#     'surface_temperature_celcius': 43},
#    {'location': (-37.0228, 148.1281),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T00:42:50',
#     'confidence': 66,
#     'surface_temperature_celcius': 43},
#    {'location': (-37.001999999999995, 148.2055),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T00:42:40',
#     'confidence': 51,
#     'surface_temperature_celcius': 44},
#    {'location': (-37.0249, 148.1561),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T00:38:10',
#     'confidence': 75,
#     'surface_temperature_celcius': 49},
#    {'location': (-37.4098, 147.0489),
#     'date': '15/03/2017',
#     'datetime': '2017-03-15T00:37:20',
#     'confidence': 70,
#     'surface_temperature_celcius': 45}]},
#  {'station': 948701,
#   'date': '16/03/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.3,
#   'windspeed_knots': 10.8,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '17/03/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 51.1,
#   'windspeed_knots': 8.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-34.3383, 141.543),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:48:20',
#     'confidence': 76,
#     'surface_temperature_celcius': 56},
#    {'location': (-36.7152, 141.3853),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:48:20',
#     'confidence': 94,
#     'surface_temperature_celcius': 74},
#    {'location': (-34.328, 141.5402),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:46:40',
#     'confidence': 78,
#     'surface_temperature_celcius': 58},
#    {'location': (-36.6867, 141.137),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:45:10',
#     'confidence': 84,
#     'surface_temperature_celcius': 59},
#    {'location': (-36.6889, 141.1239),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:45:00',
#     'confidence': 76,
#     'surface_temperature_celcius': 50},
#    {'location': (-36.7128, 141.3986),
#     'date': '17/03/2017',
#     'datetime': '2017-03-17T04:45:00',
#     'confidence': 86,
#     'surface_temperature_celcius': 60}]},
#  {'station': 948701,
#   'date': '18/03/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 52.8,
#   'windspeed_knots': 4.1,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.4313, 147.0343),
#     'date': '18/03/2017',
#     'datetime': '2017-03-18T13:16:50',
#     'confidence': 64,
#     'surface_temperature_celcius': 37},
#    {'location': (-37.016999999999996, 148.1297),
#     'date': '18/03/2017',
#     'datetime': '2017-03-18T03:50:50',
#     'confidence': 100,
#     'surface_temperature_celcius': 121},
#    {'location': (-37.0155, 148.1432),
#     'date': '18/03/2017',
#     'datetime': '2017-03-18T03:50:40',
#     'confidence': 97,
#     'surface_temperature_celcius': 80}]},
#  {'station': 948701,
#   'date': '19/03/2017',
#   'air_temperature_celcius': 24,
#   'relative_humidity': 55.2,
#   'windspeed_knots': 5.8,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.6605, 142.1116),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:39:50',
#     'confidence': 85,
#     'surface_temperature_celcius': 60},
#    {'location': (-37.9164, 143.4866),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:39:20',
#     'confidence': 58,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.6622, 142.1001),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:39:20',
#     'confidence': 96,
#     'surface_temperature_celcius': 79},
#    {'location': (-37.9257, 143.4891),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:39:20',
#     'confidence': 63,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.3982, 147.0001),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:36:00',
#     'confidence': 64,
#     'surface_temperature_celcius': 58},
#    {'location': (-37.4523, 147.0175),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:36:00',
#     'confidence': 90,
#     'surface_temperature_celcius': 66},
#    {'location': (-37.4023, 147.0394),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:35:00',
#     'confidence': 59,
#     'surface_temperature_celcius': 56},
#    {'location': (-37.4336, 147.0534),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:33:50',
#     'confidence': 60,
#     'surface_temperature_celcius': 51},
#    {'location': (-37.4003, 147.0448),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:33:30',
#     'confidence': 61,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.9184, 143.4745),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:33:30',
#     'confidence': 53,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.3911, 147.037),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:33:10',
#     'confidence': 61,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.4261, 147.0323),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:33:00',
#     'confidence': 98,
#     'surface_temperature_celcius': 83},
#    {'location': (-37.3949, 147.0175),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:50',
#     'confidence': 100,
#     'surface_temperature_celcius': 91},
#    {'location': (-37.671, 144.6536),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:50',
#     'confidence': 84,
#     'surface_temperature_celcius': 58},
#    {'location': (-37.9277, 143.477),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:50',
#     'confidence': 66,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.4224, 147.0511),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:40',
#     'confidence': 100,
#     'surface_temperature_celcius': 113},
#    {'location': (-37.6625, 144.287),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:40',
#     'confidence': 92,
#     'surface_temperature_celcius': 70},
#    {'location': (-37.4375, 147.0336),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:40',
#     'confidence': 100,
#     'surface_temperature_celcius': 106},
#    {'location': (-37.4414, 147.0139),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T04:32:40',
#     'confidence': 73,
#     'surface_temperature_celcius': 60},
#    {'location': (-37.4295, 147.0428),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T00:15:50',
#     'confidence': 77,
#     'surface_temperature_celcius': 59},
#    {'location': (-37.3942, 147.0455),
#     'date': '19/03/2017',
#     'datetime': '2017-03-19T00:12:50',
#     'confidence': 60,
#     'surface_temperature_celcius': 44}]},
#  {'station': 948701,
#   'date': '20/03/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 63.8,
#   'windspeed_knots': 7.1,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.08G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '21/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 67.4,
#   'windspeed_knots': 8.5,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.63G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '22/03/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 57.5,
#   'windspeed_knots': 16.1,
#   'max_wind_speed': 21.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '23/03/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 55.6,
#   'windspeed_knots': 12.8,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '24/03/2017',
#   'air_temperature_celcius': 20,
#   'relative_humidity': 58.4,
#   'windspeed_knots': 6.1,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.1603, 142.8088),
#     'date': '24/03/2017',
#     'datetime': '2017-03-24T04:58:00',
#     'confidence': 65,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.1684, 142.8183),
#     'date': '24/03/2017',
#     'datetime': '2017-03-24T04:56:10',
#     'confidence': 55,
#     'surface_temperature_celcius': 48}]},
#  {'station': 948701,
#   'date': '25/03/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 61.9,
#   'windspeed_knots': 8.0,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.8025, 145.8702),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T04:03:10',
#     'confidence': 76,
#     'surface_temperature_celcius': 49},
#    {'location': (-37.8992, 143.4534),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T04:03:10',
#     'confidence': 62,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.8758, 145.8371),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:59:50',
#     'confidence': 78,
#     'surface_temperature_celcius': 52},
#    {'location': (-37.8973, 143.4754),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:59:50',
#     'confidence': 82,
#     'surface_temperature_celcius': 65},
#    {'location': (-37.7829, 143.5056),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:58:10',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-37.7805, 143.5003),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:58:10',
#     'confidence': 95,
#     'surface_temperature_celcius': 75},
#    {'location': (-37.5629, 144.752),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:57:10',
#     'confidence': 85,
#     'surface_temperature_celcius': 59},
#    {'location': (-37.8122, 146.0807),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:57:10',
#     'confidence': 100,
#     'surface_temperature_celcius': 111},
#    {'location': (-37.8774, 145.8213),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:57:10',
#     'confidence': 95,
#     'surface_temperature_celcius': 77},
#    {'location': (-37.5742, 144.7536),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:56:50',
#     'confidence': 75,
#     'surface_temperature_celcius': 49},
#    {'location': (-37.8881, 145.8229),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:56:40',
#     'confidence': 100,
#     'surface_temperature_celcius': 99},
#    {'location': (-37.5612, 144.7701),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:56:40',
#     'confidence': 73,
#     'surface_temperature_celcius': 49},
#    {'location': (-37.9022, 143.4607),
#     'date': '25/03/2017',
#     'datetime': '2017-03-25T03:56:40',
#     'confidence': 57,
#     'surface_temperature_celcius': 57}]},
#  {'station': 948701,
#   'date': '26/03/2017',
#   'air_temperature_celcius': 23,
#   'relative_humidity': 60.6,
#   'windspeed_knots': 10.1,
#   'max_wind_speed': 26.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.665, 142.1339),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:47:20',
#     'confidence': 74,
#     'surface_temperature_celcius': 48},
#    {'location': (-38.0564, 142.8525),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:43:40',
#     'confidence': 74,
#     'surface_temperature_celcius': 48},
#    {'location': (-38.018, 143.899),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:43:20',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-38.1131, 143.7173),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:41:10',
#     'confidence': 68,
#     'surface_temperature_celcius': 44},
#    {'location': (-38.1106, 143.7314),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:40:50',
#     'confidence': 80,
#     'surface_temperature_celcius': 53},
#    {'location': (-37.8289, 145.9315),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:40:10',
#     'confidence': 75,
#     'surface_temperature_celcius': 49},
#    {'location': (-38.0652, 142.9781),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:50',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.522, 143.3874),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 71,
#     'surface_temperature_celcius': 73},
#    {'location': (-38.0674, 142.965),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 91,
#     'surface_temperature_celcius': 68},
#    {'location': (-38.0715, 142.9591),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 92,
#     'surface_temperature_celcius': 70},
#    {'location': (-38.0693, 142.9722),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 100,
#     'surface_temperature_celcius': 89},
#    {'location': (-37.9488, 143.8882),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 82,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.9462, 143.9026),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-37.8469, 143.5343),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 60,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.8468, 142.8775),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 84,
#     'surface_temperature_celcius': 58},
#    {'location': (-37.1956, 141.0252),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 67,
#     'surface_temperature_celcius': 44},
#    {'location': (-38.0542, 142.8655),
#     'date': '26/03/2017',
#     'datetime': '2017-03-26T04:39:10',
#     'confidence': 74,
#     'surface_temperature_celcius': 48}]},
#  {'station': 948701,
#   'date': '27/03/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 53.4,
#   'windspeed_knots': 9.4,
#   'max_wind_speed': 25.1,
#   'precipitation': ' 0.16G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '28/03/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 50.6,
#   'windspeed_knots': 6.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': [{'location': (-36.4721, 142.2586),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:38:00',
#     'confidence': 88,
#     'surface_temperature_celcius': 64},
#    {'location': (-36.7241, 141.0073),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:37:30',
#     'confidence': 72,
#     'surface_temperature_celcius': 46},
#    {'location': (-38.004, 143.9249),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:33:40',
#     'confidence': 86,
#     'surface_temperature_celcius': 60},
#    {'location': (-36.4557, 142.2434),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:33:30',
#     'confidence': 92,
#     'surface_temperature_celcius': 71},
#    {'location': (-36.8009, 142.7259),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:33:30',
#     'confidence': 95,
#     'surface_temperature_celcius': 76},
#    {'location': (-36.4737, 142.2474),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:33:20',
#     'confidence': 74,
#     'surface_temperature_celcius': 55},
#    {'location': (-36.8099, 142.72799999999998),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:32:20',
#     'confidence': 93,
#     'surface_temperature_celcius': 73},
#    {'location': (-36.8202, 141.9362),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:31:50',
#     'confidence': 76,
#     'surface_temperature_celcius': 50},
#    {'location': (-36.9576, 141.5387),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:31:50',
#     'confidence': 70,
#     'surface_temperature_celcius': 45},
#    {'location': (-36.811, 142.2655),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:50',
#     'confidence': 83,
#     'surface_temperature_celcius': 56},
#    {'location': (-34.395, 142.0522),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:20',
#     'confidence': 80,
#     'surface_temperature_celcius': 54},
#    {'location': (-36.7806, 141.5597),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 94,
#     'surface_temperature_celcius': 74},
#    {'location': (-37.639, 142.0648),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 79,
#     'surface_temperature_celcius': 52},
#    {'location': (-36.7791, 141.5711),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 72,
#     'surface_temperature_celcius': 46},
#    {'location': (-34.3526, 141.6458),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 98,
#     'surface_temperature_celcius': 82},
#    {'location': (-36.8189, 142.73),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.0924, 141.89700000000002),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 97,
#     'surface_temperature_celcius': 80},
#    {'location': (-36.4827, 142.2494),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:30:10',
#     'confidence': 77,
#     'surface_temperature_celcius': 51},
#    {'location': (-37.6195, 143.4212),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:29:30',
#     'confidence': 53,
#     'surface_temperature_celcius': 46},
#    {'location': (-34.385999999999996, 142.0503),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:28:30',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-36.8293, 141.9382),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:28:30',
#     'confidence': 79,
#     'surface_temperature_celcius': 52},
#    {'location': (-36.4573, 142.2323),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:28:30',
#     'confidence': 88,
#     'surface_temperature_celcius': 63},
#    {'location': (-37.4996, 142.5966),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:28:30',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-34.4501, 141.4699),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:28:00',
#     'confidence': 79,
#     'surface_temperature_celcius': 52},
#    {'location': (-37.9452, 143.5834),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:40',
#     'confidence': 97,
#     'surface_temperature_celcius': 80},
#    {'location': (-37.9526, 143.597),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:20',
#     'confidence': 100,
#     'surface_temperature_celcius': 107},
#    {'location': (-36.4811, 142.2606),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:20',
#     'confidence': 77,
#     'surface_temperature_celcius': 50},
#    {'location': (-36.4483, 142.2303),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:20',
#     'confidence': 76,
#     'surface_temperature_celcius': 49},
#    {'location': (-37.6269, 143.4348),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:10',
#     'confidence': 100,
#     'surface_temperature_celcius': 108},
#    {'location': (-36.7131, 142.4338),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:00',
#     'confidence': 82,
#     'surface_temperature_celcius': 55},
#    {'location': (-34.351, 141.6567),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:00',
#     'confidence': 99,
#     'surface_temperature_celcius': 86},
#    {'location': (-35.0917, 141.1508),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:27:00',
#     'confidence': 77,
#     'surface_temperature_celcius': 50},
#    {'location': (-36.6798, 141.1299),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 76,
#     'surface_temperature_celcius': 50},
#    {'location': (-36.8218, 141.9249),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 81,
#     'surface_temperature_celcius': 55},
#    {'location': (-36.82, 142.2675),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 80,
#     'surface_temperature_celcius': 53},
#    {'location': (-37.094, 141.8857),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 83,
#     'surface_temperature_celcius': 57},
#    {'location': (-37.5012, 142.5853),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 100,
#     'surface_temperature_celcius': 90},
#    {'location': (-37.6376, 143.4255),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 63,
#     'surface_temperature_celcius': 48},
#    {'location': (-37.8328, 142.5142),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 72,
#     'surface_temperature_celcius': 46},
#    {'location': (-37.8051, 143.0309),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-37.9247, 142.8999),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 97,
#     'surface_temperature_celcius': 81},
#    {'location': (-37.9231, 142.9113),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 85,
#     'surface_temperature_celcius': 59},
#    {'location': (-37.9435, 143.5948),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 88,
#     'surface_temperature_celcius': 63},
#    {'location': (-38.0221, 143.9294),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-37.1609, 149.0754),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 84,
#     'surface_temperature_celcius': 58},
#    {'location': (-36.4541, 142.2546),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 73,
#     'surface_temperature_celcius': 51},
#    {'location': (-36.4513, 141.4191),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 79,
#     'surface_temperature_celcius': 52},
#    {'location': (-36.4422, 141.4172),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 69,
#     'surface_temperature_celcius': 46},
#    {'location': (-35.0805, 142.4642),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 97,
#     'surface_temperature_celcius': 81},
#    {'location': (-36.7257, 140.9956),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 78,
#     'surface_temperature_celcius': 51},
#    {'location': (-35.0821, 142.4532),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 83,
#     'surface_temperature_celcius': 57},
#    {'location': (-36.6783, 141.1415),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 78,
#     'surface_temperature_celcius': 51},
#    {'location': (-34.3616, 141.6477),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 85,
#     'surface_temperature_celcius': 60},
#    {'location': (-34.342, 141.6548),
#     'date': '28/03/2017',
#     'datetime': '2017-03-28T04:26:50',
#     'confidence': 55,
#     'surface_temperature_celcius': 54}]},
#  {'station': 948701,
#   'date': '29/03/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 49.9,
#   'windspeed_knots': 12.2,
#   'max_wind_speed': 21.0,
#   'precipitation': ' 0.24G',
#   'Hotspot': [{'location': (-34.2648, 141.6325),
#     'date': '29/03/2017',
#     'datetime': '2017-03-29T00:48:40',
#     'confidence': 69,
#     'surface_temperature_celcius': 51}]},
#  {'station': 948701,
#   'date': '30/03/2017',
#   'air_temperature_celcius': 13,
#   'relative_humidity': 47.0,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.02G',
#   'Hotspot': []},
#  {'station': 948701,
#   'date': '31/03/2017',
#   'air_temperature_celcius': 14,
#   'relative_humidity': 45.8,
#   'windspeed_knots': 6.5,
#   'max_wind_speed': 9.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': [{'location': (-36.916, 142.0521),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T05:07:10',
#     'confidence': 82,
#     'surface_temperature_celcius': 55},
#    {'location': (-36.9116, 142.0732),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T05:01:20',
#     'confidence': 87,
#     'surface_temperature_celcius': 62},
#    {'location': (-37.3226, 143.5442),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T05:00:30',
#     'confidence': 78,
#     'surface_temperature_celcius': 51},
#    {'location': (-36.9103, 142.1409),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:59:30',
#     'confidence': 73,
#     'surface_temperature_celcius': 47},
#    {'location': (-37.7074, 143.3065),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:58:30',
#     'confidence': 82,
#     'surface_temperature_celcius': 56},
#    {'location': (-36.7056, 145.2481),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:58:10',
#     'confidence': 71,
#     'surface_temperature_celcius': 45},
#    {'location': (-36.163000000000004, 145.98),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:58:10',
#     'confidence': 79,
#     'surface_temperature_celcius': 53},
#    {'location': (-36.1722, 145.9429),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:58:00',
#     'confidence': 74,
#     'surface_temperature_celcius': 48},
#    {'location': (-36.1558, 145.9723),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:58:00',
#     'confidence': 80,
#     'surface_temperature_celcius': 53},
#    {'location': (-36.1649, 145.9352),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:50',
#     'confidence': 68,
#     'surface_temperature_celcius': 44},
#    {'location': (-36.0436, 145.7964),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:40',
#     'confidence': 68,
#     'surface_temperature_celcius': 44},
#    {'location': (-36.0362, 145.7984),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:40',
#     'confidence': 70,
#     'surface_temperature_celcius': 45},
#    {'location': (-37.5021, 142.8861),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:40',
#     'confidence': 71,
#     'surface_temperature_celcius': 48},
#    {'location': (-36.8834, 142.2701),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:20',
#     'confidence': 76,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.3301, 143.5514),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 86,
#     'surface_temperature_celcius': 61},
#    {'location': (-36.888000000000005, 142.2484),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 79,
#     'surface_temperature_celcius': 52},
#    {'location': (-36.7134, 145.2151),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 52,
#     'surface_temperature_celcius': 38},
#    {'location': (-36.7028, 145.2519),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 61,
#     'surface_temperature_celcius': 44},
#    {'location': (-37.561, 143.24200000000002),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 51,
#     'surface_temperature_celcius': 38},
#    {'location': (-37.982, 143.6422),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T04:57:10',
#     'confidence': 56,
#     'surface_temperature_celcius': 42},
#    {'location': (-34.2636, 141.6328),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T00:36:30',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-34.2568, 141.64),
#     'date': '31/03/2017',
#     'datetime': '2017-03-31T00:36:30',
# ...
#     'datetime': '2017-11-30T12:22:14',
#     'confidence': 100,
#     'surface_temperature_celcius': 71},
#    {'location': (-37.384, 149.336),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:35:00',
#     'confidence': 84,
#     'surface_temperature_celcius': 59},
#    {'location': (-37.389, 149.311),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:35:00',
#     'confidence': 73,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.605, 149.30200000000002),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:34:57',
#     'confidence': 98,
#     'surface_temperature_celcius': 83},
#    {'location': (-37.626999999999995, 149.261),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:34:57',
#     'confidence': 81,
#     'surface_temperature_celcius': 57},
#    {'location': (-37.623000000000005, 149.284),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:34:57',
#     'confidence': 84,
#     'surface_temperature_celcius': 61},
#    {'location': (-37.6, 149.325),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:34:57',
#     'confidence': 99,
#     'surface_temperature_celcius': 86},
#    {'location': (-37.61, 149.279),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T04:34:57',
#     'confidence': 69,
#     'surface_temperature_celcius': 48},
#    {'location': (-37.637, 146.28799999999998),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:21:00',
#     'confidence': 60,
#     'surface_temperature_celcius': 42},
#    {'location': (-37.608000000000004, 149.282),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 83,
#     'surface_temperature_celcius': 58},
#    {'location': (-37.62, 149.29399999999998),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 87,
#     'surface_temperature_celcius': 63},
#    {'location': (-37.618, 149.281),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 95,
#     'surface_temperature_celcius': 76},
#    {'location': (-37.61, 149.296),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 81,
#     'surface_temperature_celcius': 56},
#    {'location': (-37.603, 149.32399999999998),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 73,
#     'surface_temperature_celcius': 51},
#    {'location': (-37.602, 149.311),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 81,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.6, 149.297),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:53',
#     'confidence': 69,
#     'surface_temperature_celcius': 50},
#    {'location': (-37.382, 149.341),
#     'date': '30/11/2017',
#     'datetime': '2017-11-30T00:20:49',
#     'confidence': 64,
#     'surface_temperature_celcius': 41}]},
#  {'station': 948702,
#   'date': '1/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 59.0,
#   'windspeed_knots': 9.4,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.75G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '2/12/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 56.2,
#   'windspeed_knots': 16.9,
#   'max_wind_speed': 20.0,
#   'precipitation': ' 1.77G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '3/12/2017',
#   'air_temperature_celcius': 14,
#   'relative_humidity': 48.2,
#   'windspeed_knots': 12.5,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.03G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '4/12/2017',
#   'air_temperature_celcius': 14,
#   'relative_humidity': 48.2,
#   'windspeed_knots': 9.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '5/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 53.0,
#   'windspeed_knots': 14.6,
#   'max_wind_speed': 22.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '6/12/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 51.7,
#   'windspeed_knots': 7.4,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '7/12/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 51.0,
#   'windspeed_knots': 9.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 1.26G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '8/12/2017',
#   'air_temperature_celcius': 15,
#   'relative_humidity': 48.1,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00G',
#   'Hotspot': [{'location': (-36.273, 146.155),
#     'date': '8/12/2017',
#     'datetime': '2017-12-08T13:11:44',
#     'confidence': 77,
#     'surface_temperature_celcius': 36},
#    {'location': (-36.284, 146.145),
#     'date': '8/12/2017',
#     'datetime': '2017-12-08T13:11:44',
#     'confidence': 100,
#     'surface_temperature_celcius': 54},
#    {'location': (-36.282, 146.157),
#     'date': '8/12/2017',
#     'datetime': '2017-12-08T13:11:44',
#     'confidence': 100,
#     'surface_temperature_celcius': 71},
#    {'location': (-36.293, 146.148),
#     'date': '8/12/2017',
#     'datetime': '2017-12-08T13:11:43',
#     'confidence': 100,
#     'surface_temperature_celcius': 52},
#    {'location': (-36.291, 146.159),
#     'date': '8/12/2017',
#     'datetime': '2017-12-08T13:11:43',
#     'confidence': 56,
#     'surface_temperature_celcius': 40}]},
#  {'station': 948702,
#   'date': '9/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 53.6,
#   'windspeed_knots': 7.6,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-36.294000000000004, 146.149),
#     'date': '9/12/2017',
#     'datetime': '2017-12-09T00:14:34',
#     'confidence': 87,
#     'surface_temperature_celcius': 61},
#    {'location': (-36.285, 146.151),
#     'date': '9/12/2017',
#     'datetime': '2017-12-09T00:14:34',
#     'confidence': 81,
#     'surface_temperature_celcius': 54},
#    {'location': (-36.277, 146.165),
#     'date': '9/12/2017',
#     'datetime': '2017-12-09T00:14:33',
#     'confidence': 84,
#     'surface_temperature_celcius': 58},
#    {'location': (-36.275, 146.154),
#     'date': '9/12/2017',
#     'datetime': '2017-12-09T00:14:33',
#     'confidence': 86,
#     'surface_temperature_celcius': 60}]},
#  {'station': 948702,
#   'date': '10/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 53.5,
#   'windspeed_knots': 7.3,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.986999999999995, 144.005),
#     'date': '10/12/2017',
#     'datetime': '2017-12-10T00:57:59',
#     'confidence': 50,
#     'surface_temperature_celcius': 38},
#    {'location': (-34.289, 141.71200000000002),
#     'date': '10/12/2017',
#     'datetime': '2017-12-10T00:56:57',
#     'confidence': 67,
#     'surface_temperature_celcius': 54}]},
#  {'station': 948702,
#   'date': '11/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 52.0,
#   'windspeed_knots': 8.8,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '12/12/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 55.3,
#   'windspeed_knots': 6.2,
#   'max_wind_speed': 12.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.903, 145.25),
#     'date': '12/12/2017',
#     'datetime': '2017-12-12T00:45:38',
#     'confidence': 53,
#     'surface_temperature_celcius': 44}]},
#  {'station': 948702,
#   'date': '13/12/2017',
#   'air_temperature_celcius': 28,
#   'relative_humidity': 49.9,
#   'windspeed_knots': 11.0,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-38.231, 147.172),
#     'date': '13/12/2017',
#     'datetime': '2017-12-13T04:04:19',
#     'confidence': 83,
#     'surface_temperature_celcius': 60}]},
#  {'station': 948702,
#   'date': '14/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 52.5,
#   'windspeed_knots': 7.7,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.95, 142.366),
#     'date': '14/12/2017',
#     'datetime': '2017-12-14T04:47:25',
#     'confidence': 92,
#     'surface_temperature_celcius': 70}]},
#  {'station': 948702,
#   'date': '15/12/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 52.0,
#   'windspeed_knots': 7.1,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.626999999999995, 149.33),
#     'date': '15/12/2017',
#     'datetime': '2017-12-15T13:17:17',
#     'confidence': 92,
#     'surface_temperature_celcius': 42},
#    {'location': (-37.658, 149.339),
#     'date': '15/12/2017',
#     'datetime': '2017-12-15T13:17:17',
#     'confidence': 78,
#     'surface_temperature_celcius': 36},
#    {'location': (-37.623000000000005, 149.32299999999998),
#     'date': '15/12/2017',
#     'datetime': '2017-12-15T13:17:17',
#     'confidence': 51,
#     'surface_temperature_celcius': 38},
#    {'location': (-38.038000000000004, 142.986),
#     'date': '15/12/2017',
#     'datetime': '2017-12-15T01:16:23',
#     'confidence': 65,
#     'surface_temperature_celcius': 40}]},
#  {'station': 948702,
#   'date': '16/12/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.7,
#   'windspeed_knots': 9.0,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.635999999999996, 149.33),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T15:38:39',
#     'confidence': 94,
#     'surface_temperature_celcius': 43},
#    {'location': (-37.624, 149.332),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T15:38:39',
#     'confidence': 69,
#     'surface_temperature_celcius': 33},
#    {'location': (-37.82, 142.32299999999998),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:35:15',
#     'confidence': 62,
#     'surface_temperature_celcius': 54},
#    {'location': (-37.875, 142.51),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:35:13',
#     'confidence': 93,
#     'surface_temperature_celcius': 73},
#    {'location': (-37.608000000000004, 149.328),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:58',
#     'confidence': 84,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.613, 149.305),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:58',
#     'confidence': 95,
#     'surface_temperature_celcius': 75},
#    {'location': (-37.644, 149.346),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:57',
#     'confidence': 59,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.624, 149.314),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:57',
#     'confidence': 90,
#     'surface_temperature_celcius': 66},
#    {'location': (-37.661, 149.327),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:57',
#     'confidence': 75,
#     'surface_temperature_celcius': 56},
#    {'location': (-37.649, 149.322),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T04:34:57',
#     'confidence': 79,
#     'surface_temperature_celcius': 60},
#    {'location': (-38.056999999999995, 144.211),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T00:21:12',
#     'confidence': 93,
#     'surface_temperature_celcius': 73},
#    {'location': (-38.046, 144.201),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T00:21:11',
#     'confidence': 60,
#     'surface_temperature_celcius': 48},
#    {'location': (-38.048, 144.213),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T00:21:11',
#     'confidence': 82,
#     'surface_temperature_celcius': 55},
#    {'location': (-37.650999999999996, 149.345),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T00:20:53',
#     'confidence': 82,
#     'surface_temperature_celcius': 64},
#    {'location': (-37.63, 149.335),
#     'date': '16/12/2017',
#     'datetime': '2017-12-16T00:20:53',
#     'confidence': 53,
#     'surface_temperature_celcius': 57}]},
#  {'station': 948702,
#   'date': '17/12/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 58.7,
#   'windspeed_knots': 7.8,
#   'max_wind_speed': 13.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '18/12/2017',
#   'air_temperature_celcius': 25,
#   'relative_humidity': 60.9,
#   'windspeed_knots': 6.3,
#   'max_wind_speed': 8.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '19/12/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 57.4,
#   'windspeed_knots': 10.7,
#   'max_wind_speed': 22.9,
#   'precipitation': ' 0.67G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '20/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 51.2,
#   'windspeed_knots': 9.9,
#   'max_wind_speed': 18.1,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '21/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 52.5,
#   'windspeed_knots': 5.7,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-38.075, 143.76),
#     'date': '21/12/2017',
#     'datetime': '2017-12-21T04:53:29',
#     'confidence': 72,
#     'surface_temperature_celcius': 46}]},
#  {'station': 948702,
#   'date': '22/12/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 55.8,
#   'windspeed_knots': 6.0,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '23/12/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 53.9,
#   'windspeed_knots': 8.3,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '24/12/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 47.0,
#   'windspeed_knots': 12.0,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-35.646, 142.282),
#     'date': '24/12/2017',
#     'datetime': '2017-12-24T13:12:01',
#     'confidence': 65,
#     'surface_temperature_celcius': 32}]},
#  {'station': 948702,
#   'date': '25/12/2017',
#   'air_temperature_celcius': 17,
#   'relative_humidity': 50.4,
#   'windspeed_knots': 10.8,
#   'max_wind_speed': 16.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.708, 145.1),
#     'date': '25/12/2017',
#     'datetime': '2017-12-25T04:29:08',
#     'confidence': 80,
#     'surface_temperature_celcius': 54}]},
#  {'station': 948702,
#   'date': '26/12/2017',
#   'air_temperature_celcius': 22,
#   'relative_humidity': 55.5,
#   'windspeed_knots': 10.3,
#   'max_wind_speed': 19.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '27/12/2017',
#   'air_temperature_celcius': 28,
#   'relative_humidity': 58.3,
#   'windspeed_knots': 9.3,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00I',
#   'Hotspot': [{'location': (-37.966, 145.05100000000002),
#     'date': '27/12/2017',
#     'datetime': '2017-12-27T04:16:51',
#     'confidence': 78,
#     'surface_temperature_celcius': 68},
#    {'location': (-35.541, 143.311),
#     'date': '27/12/2017',
#     'datetime': '2017-12-27T00:02:15',
#     'confidence': 82,
#     'surface_temperature_celcius': 63},
#    {'location': (-35.554, 143.30700000000002),
#     'date': '27/12/2017',
#     'datetime': '2017-12-27T00:02:15',
#     'confidence': 67,
#     'surface_temperature_celcius': 53},
#    {'location': (-35.543, 143.316),
#     'date': '27/12/2017',
#     'datetime': '2017-12-27T00:02:14',
#     'confidence': 86,
#     'surface_temperature_celcius': 67}]},
#  {'station': 948702,
#   'date': '28/12/2017',
#   'air_temperature_celcius': 21,
#   'relative_humidity': 61.1,
#   'windspeed_knots': 6.6,
#   'max_wind_speed': 11.1,
#   'precipitation': ' 0.00I',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '29/12/2017',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 59.7,
#   'windspeed_knots': 7.4,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.63G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '30/12/2017',
#   'air_temperature_celcius': 16,
#   'relative_humidity': 51.5,
#   'windspeed_knots': 8.7,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.02G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '31/12/2017',
#   'air_temperature_celcius': 18,
#   'relative_humidity': 53.6,
#   'windspeed_knots': 7.9,
#   'max_wind_speed': 15.9,
#   'precipitation': ' 0.00G',
#   'Hotspot': []},
#  {'station': 948702,
#   'date': '1/01/2018',
#   'air_temperature_celcius': 19,
#   'relative_humidity': 52.9,
#   'windspeed_knots': 8.1,
#   'max_wind_speed': 15.0,
#   'precipitation': ' 0.00I',
#   'Hotspot': []}]

# %%
# creating another list for hotspot_list
hotspot_list = []
# appending the hotspot data to the newly created dictionary
for i in hotspot_data:
    dic = {}
    dic['latitude'] = i[0]
    dic['longitude'] = i[1]
    dic['datetime'] = i[2]
    dic['confidence'] = i[3]
    dic['date'] = i[4]
    dic['surface_temperature_celcius'] = i[5]
    
    hotspot_list.append(dic)
len(hotspot_list)
# Out:
# 2668

# %%
hotspot_list
# Out:
# [{'latitude': -37.966,
#   'longitude': 145.05100000000002,
#   'datetime': '2017-12-27T04:16:51',
#   'confidence': 78,
#   'date': '27/12/2017',
#   'surface_temperature_celcius': 68},
#  {'latitude': -35.541,
#   'longitude': 143.311,
#   'datetime': '2017-12-27T00:02:15',
#   'confidence': 82,
#   'date': '27/12/2017',
#   'surface_temperature_celcius': 63},
#  {'latitude': -35.554,
#   'longitude': 143.30700000000002,
#   'datetime': '2017-12-27T00:02:15',
#   'confidence': 67,
#   'date': '27/12/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -35.543,
#   'longitude': 143.316,
#   'datetime': '2017-12-27T00:02:14',
#   'confidence': 86,
#   'date': '27/12/2017',
#   'surface_temperature_celcius': 67},
#  {'latitude': -37.708,
#   'longitude': 145.1,
#   'datetime': '2017-12-25T04:29:08',
#   'confidence': 80,
#   'date': '25/12/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -35.646,
#   'longitude': 142.282,
#   'datetime': '2017-12-24T13:12:01',
#   'confidence': 65,
#   'date': '24/12/2017',
#   'surface_temperature_celcius': 32},
#  {'latitude': -38.075,
#   'longitude': 143.76,
#   'datetime': '2017-12-21T04:53:29',
#   'confidence': 72,
#   'date': '21/12/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.635999999999996,
#   'longitude': 149.33,
#   'datetime': '2017-12-16T15:38:39',
#   'confidence': 94,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.624,
#   'longitude': 149.332,
#   'datetime': '2017-12-16T15:38:39',
#   'confidence': 69,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 33},
#  {'latitude': -37.82,
#   'longitude': 142.32299999999998,
#   'datetime': '2017-12-16T04:35:15',
#   'confidence': 62,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.875,
#   'longitude': 142.51,
#   'datetime': '2017-12-16T04:35:13',
#   'confidence': 93,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 73},
#  {'latitude': -37.608000000000004,
#   'longitude': 149.328,
#   'datetime': '2017-12-16T04:34:58',
#   'confidence': 84,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.613,
#   'longitude': 149.305,
#   'datetime': '2017-12-16T04:34:58',
#   'confidence': 95,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 75},
#  {'latitude': -37.644,
#   'longitude': 149.346,
#   'datetime': '2017-12-16T04:34:57',
#   'confidence': 59,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.624,
#   'longitude': 149.314,
#   'datetime': '2017-12-16T04:34:57',
#   'confidence': 90,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 66},
#  {'latitude': -37.661,
#   'longitude': 149.327,
#   'datetime': '2017-12-16T04:34:57',
#   'confidence': 75,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -37.649,
#   'longitude': 149.322,
#   'datetime': '2017-12-16T04:34:57',
#   'confidence': 79,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -38.056999999999995,
#   'longitude': 144.211,
#   'datetime': '2017-12-16T00:21:12',
#   'confidence': 93,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 73},
#  {'latitude': -38.046,
#   'longitude': 144.201,
#   'datetime': '2017-12-16T00:21:11',
#   'confidence': 60,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -38.048,
#   'longitude': 144.213,
#   'datetime': '2017-12-16T00:21:11',
#   'confidence': 82,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.650999999999996,
#   'longitude': 149.345,
#   'datetime': '2017-12-16T00:20:53',
#   'confidence': 82,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 64},
#  {'latitude': -37.63,
#   'longitude': 149.335,
#   'datetime': '2017-12-16T00:20:53',
#   'confidence': 53,
#   'date': '16/12/2017',
#   'surface_temperature_celcius': 57},
#  {'latitude': -37.626999999999995,
#   'longitude': 149.33,
#   'datetime': '2017-12-15T13:17:17',
#   'confidence': 92,
#   'date': '15/12/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.658,
#   'longitude': 149.339,
#   'datetime': '2017-12-15T13:17:17',
#   'confidence': 78,
#   'date': '15/12/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -37.623000000000005,
#   'longitude': 149.32299999999998,
#   'datetime': '2017-12-15T13:17:17',
#   'confidence': 51,
#   'date': '15/12/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -38.038000000000004,
#   'longitude': 142.986,
#   'datetime': '2017-12-15T01:16:23',
#   'confidence': 65,
#   'date': '15/12/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -37.95,
#   'longitude': 142.366,
#   'datetime': '2017-12-14T04:47:25',
#   'confidence': 92,
#   'date': '14/12/2017',
#   'surface_temperature_celcius': 70},
#  {'latitude': -38.231,
#   'longitude': 147.172,
#   'datetime': '2017-12-13T04:04:19',
#   'confidence': 83,
#   'date': '13/12/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -37.903,
#   'longitude': 145.25,
#   'datetime': '2017-12-12T00:45:38',
#   'confidence': 53,
#   'date': '12/12/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.986999999999995,
#   'longitude': 144.005,
#   'datetime': '2017-12-10T00:57:59',
#   'confidence': 50,
#   'date': '10/12/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -34.289,
#   'longitude': 141.71200000000002,
#   'datetime': '2017-12-10T00:56:57',
#   'confidence': 67,
#   'date': '10/12/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -36.294000000000004,
#   'longitude': 146.149,
#   'datetime': '2017-12-09T00:14:34',
#   'confidence': 87,
#   'date': '9/12/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -36.285,
#   'longitude': 146.151,
#   'datetime': '2017-12-09T00:14:34',
#   'confidence': 81,
#   'date': '9/12/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -36.277,
#   'longitude': 146.165,
#   'datetime': '2017-12-09T00:14:33',
#   'confidence': 84,
#   'date': '9/12/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -36.275,
#   'longitude': 146.154,
#   'datetime': '2017-12-09T00:14:33',
#   'confidence': 86,
#   'date': '9/12/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.273,
#   'longitude': 146.155,
#   'datetime': '2017-12-08T13:11:44',
#   'confidence': 77,
#   'date': '8/12/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -36.284,
#   'longitude': 146.145,
#   'datetime': '2017-12-08T13:11:44',
#   'confidence': 100,
#   'date': '8/12/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -36.282,
#   'longitude': 146.157,
#   'datetime': '2017-12-08T13:11:44',
#   'confidence': 100,
#   'date': '8/12/2017',
#   'surface_temperature_celcius': 71},
#  {'latitude': -36.293,
#   'longitude': 146.148,
#   'datetime': '2017-12-08T13:11:43',
#   'confidence': 100,
#   'date': '8/12/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -36.291,
#   'longitude': 146.159,
#   'datetime': '2017-12-08T13:11:43',
#   'confidence': 56,
#   'date': '8/12/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -37.635,
#   'longitude': 149.303,
#   'datetime': '2017-11-30T23:25:57',
#   'confidence': 52,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -37.591,
#   'longitude': 149.33,
#   'datetime': '2017-11-30T15:38:36',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -37.59,
#   'longitude': 149.31,
#   'datetime': '2017-11-30T15:38:36',
#   'confidence': 51,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.633,
#   'longitude': 149.264,
#   'datetime': '2017-11-30T15:38:36',
#   'confidence': 64,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.585,
#   'longitude': 149.336,
#   'datetime': '2017-11-30T15:38:35',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.58,
#   'longitude': 149.33100000000002,
#   'datetime': '2017-11-30T15:38:35',
#   'confidence': 69,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.583,
#   'longitude': 149.316,
#   'datetime': '2017-11-30T15:38:35',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.38,
#   'longitude': 149.334,
#   'datetime': '2017-11-30T15:38:32',
#   'confidence': 61,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 31},
#  {'latitude': -37.602,
#   'longitude': 149.295,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 62,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 33},
#  {'latitude': -37.598,
#   'longitude': 149.29,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 64,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 32},
#  {'latitude': -37.596,
#   'longitude': 149.319,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 84,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -37.63,
#   'longitude': 149.232,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 81,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.644,
#   'longitude': 149.233,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.641999999999996,
#   'longitude': 149.263,
#   'datetime': '2017-11-30T12:22:15',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.634,
#   'longitude': 149.237,
#   'datetime': '2017-11-30T12:22:14',
#   'confidence': 100,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 71},
#  {'latitude': -37.384,
#   'longitude': 149.336,
#   'datetime': '2017-11-30T04:35:00',
#   'confidence': 84,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.389,
#   'longitude': 149.311,
#   'datetime': '2017-11-30T04:35:00',
#   'confidence': 73,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.605,
#   'longitude': 149.30200000000002,
#   'datetime': '2017-11-30T04:34:57',
#   'confidence': 98,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 83},
#  {'latitude': -37.626999999999995,
#   'longitude': 149.261,
#   'datetime': '2017-11-30T04:34:57',
#   'confidence': 81,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 57},
#  {'latitude': -37.623000000000005,
#   'longitude': 149.284,
#   'datetime': '2017-11-30T04:34:57',
#   'confidence': 84,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.6,
#   'longitude': 149.325,
#   'datetime': '2017-11-30T04:34:57',
#   'confidence': 99,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 86},
#  {'latitude': -37.61,
#   'longitude': 149.279,
#   'datetime': '2017-11-30T04:34:57',
#   'confidence': 69,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -37.637,
#   'longitude': 146.28799999999998,
#   'datetime': '2017-11-30T00:21:00',
#   'confidence': 60,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.608000000000004,
#   'longitude': 149.282,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 83,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -37.62,
#   'longitude': 149.29399999999998,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 87,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 63},
#  {'latitude': -37.618,
#   'longitude': 149.281,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 95,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 76},
#  {'latitude': -37.61,
#   'longitude': 149.296,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 81,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -37.603,
#   'longitude': 149.32399999999998,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 73,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.602,
#   'longitude': 149.311,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 81,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.6,
#   'longitude': 149.297,
#   'datetime': '2017-11-30T00:20:53',
#   'confidence': 69,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.382,
#   'longitude': 149.341,
#   'datetime': '2017-11-30T00:20:49',
#   'confidence': 64,
#   'date': '30/11/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.611,
#   'longitude': 149.27700000000002,
#   'datetime': '2017-11-29T13:17:24',
#   'confidence': 53,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -37.608000000000004,
#   'longitude': 149.292,
#   'datetime': '2017-11-29T13:17:24',
#   'confidence': 100,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.605,
#   'longitude': 149.308,
#   'datetime': '2017-11-29T13:17:24',
#   'confidence': 68,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -34.282,
#   'longitude': 142.121,
#   'datetime': '2017-11-29T03:53:16',
#   'confidence': 52,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.606,
#   'longitude': 149.312,
#   'datetime': '2017-11-29T03:52:10',
#   'confidence': 100,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 87},
#  {'latitude': -37.605,
#   'longitude': 149.326,
#   'datetime': '2017-11-29T03:52:10',
#   'confidence': 64,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.61,
#   'longitude': 149.30700000000002,
#   'datetime': '2017-11-29T03:52:10',
#   'confidence': 97,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 80},
#  {'latitude': -37.609,
#   'longitude': 149.32,
#   'datetime': '2017-11-29T03:52:10',
#   'confidence': 99,
#   'date': '29/11/2017',
#   'surface_temperature_celcius': 84},
#  {'latitude': -37.749,
#   'longitude': 148.297,
#   'datetime': '2017-11-28T00:33:14',
#   'confidence': 50,
#   'date': '28/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.946,
#   'longitude': 144.342,
#   'datetime': '2017-11-23T04:28:59',
#   'confidence': 84,
#   'date': '23/11/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -37.945,
#   'longitude': 144.35399999999998,
#   'datetime': '2017-11-23T04:28:59',
#   'confidence': 93,
#   'date': '23/11/2017',
#   'surface_temperature_celcius': 73},
#  {'latitude': -38.141,
#   'longitude': 143.183,
#   'datetime': '2017-11-23T00:15:12',
#   'confidence': 68,
#   'date': '23/11/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -36.952,
#   'longitude': 144.972,
#   'datetime': '2017-11-23T00:14:47',
#   'confidence': 63,
#   'date': '23/11/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -34.965,
#   'longitude': 142.031,
#   'datetime': '2017-11-23T00:14:24',
#   'confidence': 70,
#   'date': '23/11/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.978,
#   'longitude': 145.623,
#   'datetime': '2017-11-22T03:46:00',
#   'confidence': 84,
#   'date': '22/11/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.976,
#   'longitude': 145.649,
#   'datetime': '2017-11-22T03:46:00',
#   'confidence': 88,
#   'date': '22/11/2017',
#   'surface_temperature_celcius': 64},
#  {'latitude': -37.758,
#   'longitude': 144.69299999999998,
#   'datetime': '2017-11-21T00:27:21',
#   'confidence': 85,
#   'date': '21/11/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.861999999999995,
#   'longitude': 144.175,
#   'datetime': '2017-11-14T04:35:04',
#   'confidence': 87,
#   'date': '14/11/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -38.527,
#   'longitude': 143.493,
#   'datetime': '2017-11-14T00:21:26',
#   'confidence': 64,
#   'date': '14/11/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -37.332,
#   'longitude': 143.375,
#   'datetime': '2017-11-14T00:21:07',
#   'confidence': 64,
#   'date': '14/11/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.621,
#   'longitude': 143.447,
#   'datetime': '2017-11-13T03:52:15',
#   'confidence': 87,
#   'date': '13/11/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.614000000000004,
#   'longitude': 143.451,
#   'datetime': '2017-11-13T03:52:14',
#   'confidence': 81,
#   'date': '13/11/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -37.954,
#   'longitude': 143.918,
#   'datetime': '2017-11-13T03:52:08',
#   'confidence': 64,
#   'date': '13/11/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -38.167,
#   'longitude': 143.841,
#   'datetime': '2017-11-13T01:16:38',
#   'confidence': 51,
#   'date': '13/11/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -38.16,
#   'longitude': 143.803,
#   'datetime': '2017-11-13T01:16:37',
#   'confidence': 62,
#   'date': '13/11/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -36.942,
#   'longitude': 143.282,
#   'datetime': '2017-11-12T04:47:32',
#   'confidence': 63,
#   'date': '12/11/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -37.864000000000004,
#   'longitude': 144.174,
#   'datetime': '2017-11-12T04:47:16',
#   'confidence': 58,
#   'date': '12/11/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -38.912,
#   'longitude': 146.27200000000002,
#   'datetime': '2017-11-12T04:46:53',
#   'confidence': 56,
#   'date': '12/11/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -36.942,
#   'longitude': 143.292,
#   'datetime': '2017-11-12T00:33:15',
#   'confidence': 67,
#   'date': '12/11/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -36.94,
#   'longitude': 143.281,
#   'datetime': '2017-11-12T00:33:15',
#   'confidence': 89,
#   'date': '12/11/2017',
#   'surface_temperature_celcius': 69},
#  {'latitude': -36.943000000000005,
#   'longitude': 143.286,
#   'datetime': '2017-11-11T15:08:00',
#   'confidence': 51,
#   'date': '11/11/2017',
#   'surface_temperature_celcius': 29},
#  {'latitude': -36.941,
#   'longitude': 143.268,
#   'datetime': '2017-11-11T13:30:08',
#   'confidence': 80,
#   'date': '11/11/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -36.939,
#   'longitude': 143.28,
#   'datetime': '2017-11-11T13:30:08',
#   'confidence': 100,
#   'date': '11/11/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.863,
#   'longitude': 144.17,
#   'datetime': '2017-11-11T04:04:25',
#   'confidence': 86,
#   'date': '11/11/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.759,
#   'longitude': 145.179,
#   'datetime': '2017-11-09T04:16:56',
#   'confidence': 68,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -36.758,
#   'longitude': 145.19,
#   'datetime': '2017-11-09T04:16:56',
#   'confidence': 62,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.213,
#   'longitude': 142.941,
#   'datetime': '2017-11-09T04:16:53',
#   'confidence': 75,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.479,
#   'longitude': 143.358,
#   'datetime': '2017-11-09T04:16:48',
#   'confidence': 85,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.467,
#   'longitude': 143.351,
#   'datetime': '2017-11-09T04:16:48',
#   'confidence': 72,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -37.477,
#   'longitude': 143.352,
#   'datetime': '2017-11-09T04:16:48',
#   'confidence': 100,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 93},
#  {'latitude': -37.475,
#   'longitude': 143.365,
#   'datetime': '2017-11-09T04:16:48',
#   'confidence': 96,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 77},
#  {'latitude': -37.719,
#   'longitude': 142.154,
#   'datetime': '2017-11-09T04:16:46',
#   'confidence': 63,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.692,
#   'longitude': 143.593,
#   'datetime': '2017-11-09T04:16:44',
#   'confidence': 87,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 62},
#  {'latitude': -37.69,
#   'longitude': 143.605,
#   'datetime': '2017-11-09T04:16:44',
#   'confidence': 97,
#   'date': '9/11/2017',
#   'surface_temperature_celcius': 80},
#  {'latitude': -36.538000000000004,
#   'longitude': 141.129,
#   'datetime': '2017-11-08T05:12:08',
#   'confidence': 60,
#   'date': '8/11/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -36.543,
#   'longitude': 141.138,
#   'datetime': '2017-11-08T05:12:08',
#   'confidence': 72,
#   'date': '8/11/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -36.341,
#   'longitude': 143.636,
#   'datetime': '2017-11-05T04:41:34',
#   'confidence': 83,
#   'date': '5/11/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -36.346,
#   'longitude': 143.631,
#   'datetime': '2017-11-05T04:41:34',
#   'confidence': 71,
#   'date': '5/11/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.330999999999996,
#   'longitude': 143.122,
#   'datetime': '2017-11-05T04:41:19',
#   'confidence': 90,
#   'date': '5/11/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.329,
#   'longitude': 143.136,
#   'datetime': '2017-11-05T04:41:19',
#   'confidence': 89,
#   'date': '5/11/2017',
#   'surface_temperature_celcius': 62},
#  {'latitude': -37.34,
#   'longitude': 143.123,
#   'datetime': '2017-10-28T03:52:17',
#   'confidence': 81,
#   'date': '28/10/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -36.748000000000005,
#   'longitude': 144.168,
#   'datetime': '2017-10-27T04:47:31',
#   'confidence': 62,
#   'date': '27/10/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.751999999999995,
#   'longitude': 144.15,
#   'datetime': '2017-10-27T04:47:31',
#   'confidence': 78,
#   'date': '27/10/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -36.759,
#   'longitude': 144.158,
#   'datetime': '2017-10-27T04:47:31',
#   'confidence': 86,
#   'date': '27/10/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.764,
#   'longitude': 144.165,
#   'datetime': '2017-10-27T00:33:09',
#   'confidence': 78,
#   'date': '27/10/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -36.765,
#   'longitude': 144.17600000000002,
#   'datetime': '2017-10-27T00:33:09',
#   'confidence': 74,
#   'date': '27/10/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -35.325,
#   'longitude': 143.497,
#   'datetime': '2017-10-26T13:30:31',
#   'confidence': 77,
#   'date': '26/10/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -35.321,
#   'longitude': 143.502,
#   'datetime': '2017-10-26T13:30:31',
#   'confidence': 100,
#   'date': '26/10/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -35.323,
#   'longitude': 143.509,
#   'datetime': '2017-10-26T13:30:31',
#   'confidence': 100,
#   'date': '26/10/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -36.156,
#   'longitude': 143.56799999999998,
#   'datetime': '2017-10-26T04:04:53',
#   'confidence': 67,
#   'date': '26/10/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -36.152,
#   'longitude': 143.578,
#   'datetime': '2017-10-26T04:04:53',
#   'confidence': 69,
#   'date': '26/10/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.297,
#   'longitude': 144.384,
#   'datetime': '2017-10-23T00:57:55',
#   'confidence': 72,
#   'date': '23/10/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -36.1,
#   'longitude': 143.767,
#   'datetime': '2017-10-21T01:09:55',
#   'confidence': 77,
#   'date': '21/10/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.098,
#   'longitude': 143.735,
#   'datetime': '2017-10-21T01:09:55',
#   'confidence': 88,
#   'date': '21/10/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -36.1,
#   'longitude': 143.77200000000002,
#   'datetime': '2017-10-21T01:09:54',
#   'confidence': 65,
#   'date': '21/10/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -36.098,
#   'longitude': 143.74,
#   'datetime': '2017-10-21T01:09:54',
#   'confidence': 92,
#   'date': '21/10/2017',
#   'surface_temperature_celcius': 67},
#  {'latitude': -37.586,
#   'longitude': 141.27100000000002,
#   'datetime': '2017-10-20T04:41:19',
#   'confidence': 80,
#   'date': '20/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.588,
#   'longitude': 141.259,
#   'datetime': '2017-10-20T04:41:19',
#   'confidence': 82,
#   'date': '20/10/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.296,
#   'longitude': 144.386,
#   'datetime': '2017-10-20T00:27:12',
#   'confidence': 65,
#   'date': '20/10/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.287,
#   'longitude': 144.392,
#   'datetime': '2017-10-18T00:39:27',
#   'confidence': 79,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.295,
#   'longitude': 144.377,
#   'datetime': '2017-10-18T00:39:27',
#   'confidence': 75,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -35.364000000000004,
#   'longitude': 141.063,
#   'datetime': '2017-10-18T00:39:03',
#   'confidence': 72,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -35.89,
#   'longitude': 145.606,
#   'datetime': '2017-10-18T00:39:02',
#   'confidence': 84,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -35.889,
#   'longitude': 145.614,
#   'datetime': '2017-10-18T00:39:02',
#   'confidence': 82,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -35.891999999999996,
#   'longitude': 145.62,
#   'datetime': '2017-10-18T00:39:02',
#   'confidence': 71,
#   'date': '18/10/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.247,
#   'longitude': 141.27,
#   'datetime': '2017-10-17T13:36:12',
#   'confidence': 94,
#   'date': '17/10/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -35.937,
#   'longitude': 145.607,
#   'datetime': '2017-10-17T04:10:59',
#   'confidence': 73,
#   'date': '17/10/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.247,
#   'longitude': 141.278,
#   'datetime': '2017-10-17T04:10:45',
#   'confidence': 91,
#   'date': '17/10/2017',
#   'surface_temperature_celcius': 68},
#  {'latitude': -37.586999999999996,
#   'longitude': 142.47899999999998,
#   'datetime': '2017-10-17T04:10:38',
#   'confidence': 58,
#   'date': '17/10/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.805,
#   'longitude': 144.15,
#   'datetime': '2017-10-17T04:10:32',
#   'confidence': 82,
#   'date': '17/10/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.288000000000004,
#   'longitude': 144.39,
#   'datetime': '2017-10-16T23:56:43',
#   'confidence': 62,
#   'date': '16/10/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -37.294000000000004,
#   'longitude': 141.232,
#   'datetime': '2017-10-15T04:23:01',
#   'confidence': 100,
#   'date': '15/10/2017',
#   'surface_temperature_celcius': 87},
#  {'latitude': -37.293,
#   'longitude': 141.245,
#   'datetime': '2017-10-15T04:23:01',
#   'confidence': 99,
#   'date': '15/10/2017',
#   'surface_temperature_celcius': 85},
#  {'latitude': -36.851,
#   'longitude': 148.11700000000002,
#   'datetime': '2017-10-15T00:08:42',
#   'confidence': 78,
#   'date': '15/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.249,
#   'longitude': 143.41299999999998,
#   'datetime': '2017-10-10T04:04:34',
#   'confidence': 72,
#   'date': '10/10/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -38.126999999999995,
#   'longitude': 143.82,
#   'datetime': '2017-10-10T04:04:19',
#   'confidence': 96,
#   'date': '10/10/2017',
#   'surface_temperature_celcius': 77},
#  {'latitude': -38.116,
#   'longitude': 143.81799999999998,
#   'datetime': '2017-10-10T04:04:19',
#   'confidence': 76,
#   'date': '10/10/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.245,
#   'longitude': 143.42600000000002,
#   'datetime': '2017-10-09T00:45:42',
#   'confidence': 78,
#   'date': '9/10/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.091,
#   'longitude': 145.362,
#   'datetime': '2017-10-08T04:16:48',
#   'confidence': 72,
#   'date': '8/10/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.086999999999996,
#   'longitude': 145.363,
#   'datetime': '2017-10-07T12:59:33',
#   'confidence': 91,
#   'date': '7/10/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -35.961999999999996,
#   'longitude': 143.791,
#   'datetime': '2017-10-06T04:29:25',
#   'confidence': 76,
#   'date': '6/10/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -36.498000000000005,
#   'longitude': 144.877,
#   'datetime': '2017-10-06T04:29:13',
#   'confidence': 77,
#   'date': '6/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -36.418,
#   'longitude': 141.596,
#   'datetime': '2017-10-04T04:41:36',
#   'confidence': 50,
#   'date': '4/10/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.38,
#   'longitude': 148.053,
#   'datetime': '2017-10-04T04:41:02',
#   'confidence': 80,
#   'date': '4/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.466,
#   'longitude': 148.143,
#   'datetime': '2017-10-04T04:41:00',
#   'confidence': 80,
#   'date': '4/10/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -37.472,
#   'longitude': 148.119,
#   'datetime': '2017-10-04T04:41:00',
#   'confidence': 85,
#   'date': '4/10/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.469,
#   'longitude': 148.125,
#   'datetime': '2017-10-04T04:41:00',
#   'confidence': 88,
#   'date': '4/10/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -37.461,
#   'longitude': 148.109,
#   'datetime': '2017-10-03T15:01:44',
#   'confidence': 69,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 33},
#  {'latitude': -37.459,
#   'longitude': 148.092,
#   'datetime': '2017-10-03T13:23:43',
#   'confidence': 92,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.236,
#   'longitude': 141.17600000000002,
#   'datetime': '2017-10-03T03:58:28',
#   'confidence': 68,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -37.227,
#   'longitude': 141.151,
#   'datetime': '2017-10-03T03:58:28',
#   'confidence': 59,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.242,
#   'longitude': 141.153,
#   'datetime': '2017-10-03T03:58:28',
#   'confidence': 77,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.238,
#   'longitude': 141.145,
#   'datetime': '2017-10-03T03:58:28',
#   'confidence': 76,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.365,
#   'longitude': 148.05200000000002,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 90,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 63},
#  {'latitude': -37.376,
#   'longitude': 148.042,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 81,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -37.375,
#   'longitude': 148.054,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 82,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.385999999999996,
#   'longitude': 148.043,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 84,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.384,
#   'longitude': 148.056,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 90,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 63},
#  {'latitude': -37.367,
#   'longitude': 148.04,
#   'datetime': '2017-10-03T03:58:15',
#   'confidence': 71,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -37.471,
#   'longitude': 148.091,
#   'datetime': '2017-10-03T03:58:14',
#   'confidence': 71,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.461999999999996,
#   'longitude': 148.089,
#   'datetime': '2017-10-03T03:58:14',
#   'confidence': 100,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 90},
#  {'latitude': -37.46,
#   'longitude': 148.102,
#   'datetime': '2017-10-03T03:58:14',
#   'confidence': 88,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.469,
#   'longitude': 148.10299999999998,
#   'datetime': '2017-10-03T03:58:14',
#   'confidence': 87,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.229,
#   'longitude': 141.18200000000002,
#   'datetime': '2017-10-03T01:22:44',
#   'confidence': 73,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -37.227,
#   'longitude': 141.14600000000002,
#   'datetime': '2017-10-03T01:22:44',
#   'confidence': 54,
#   'date': '3/10/2017',
#   'surface_temperature_celcius': 31},
#  {'latitude': -37.466,
#   'longitude': 148.1,
#   'datetime': '2017-10-02T23:44:31',
#   'confidence': 50,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 29},
#  {'latitude': -37.475,
#   'longitude': 148.134,
#   'datetime': '2017-10-02T04:53:10',
#   'confidence': 59,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -37.47,
#   'longitude': 148.089,
#   'datetime': '2017-10-02T04:53:10',
#   'confidence': 83,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.485,
#   'longitude': 148.095,
#   'datetime': '2017-10-02T04:53:10',
#   'confidence': 71,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.477,
#   'longitude': 148.097,
#   'datetime': '2017-10-02T04:53:09',
#   'confidence': 85,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.461,
#   'longitude': 148.105,
#   'datetime': '2017-10-02T00:39:34',
#   'confidence': 76,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.455999999999996,
#   'longitude': 148.11,
#   'datetime': '2017-10-02T00:39:34',
#   'confidence': 68,
#   'date': '2/10/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -37.463,
#   'longitude': 148.109,
#   'datetime': '2017-10-01T15:13:56',
#   'confidence': 62,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 34},
#  {'latitude': -37.453,
#   'longitude': 148.111,
#   'datetime': '2017-10-01T15:13:56',
#   'confidence': 100,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.461,
#   'longitude': 148.10299999999998,
#   'datetime': '2017-10-01T13:36:02',
#   'confidence': 77,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -37.368,
#   'longitude': 148.05,
#   'datetime': '2017-10-01T04:10:30',
#   'confidence': 79,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -37.478,
#   'longitude': 148.11700000000002,
#   'datetime': '2017-10-01T04:10:28',
#   'confidence': 84,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -37.467,
#   'longitude': 148.127,
#   'datetime': '2017-10-01T04:10:28',
#   'confidence': 89,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.46,
#   'longitude': 148.113,
#   'datetime': '2017-10-01T04:10:28',
#   'confidence': 64,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -37.453,
#   'longitude': 148.099,
#   'datetime': '2017-10-01T04:10:28',
#   'confidence': 78,
#   'date': '1/10/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.45,
#   'longitude': 148.097,
#   'datetime': '2017-09-29T04:22:41',
#   'confidence': 70,
#   'date': '29/09/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -38.226,
#   'longitude': 147.167,
#   'datetime': '2017-09-29T04:22:31',
#   'confidence': 82,
#   'date': '29/09/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -35.954,
#   'longitude': 141.076,
#   'datetime': '2017-09-27T04:35:36',
#   'confidence': 78,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -35.961,
#   'longitude': 141.089,
#   'datetime': '2017-09-27T04:35:36',
#   'confidence': 83,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -35.963,
#   'longitude': 141.078,
#   'datetime': '2017-09-27T04:35:36',
#   'confidence': 86,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.275,
#   'longitude': 142.785,
#   'datetime': '2017-09-27T04:35:27',
#   'confidence': 72,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -36.398,
#   'longitude': 145.286,
#   'datetime': '2017-09-27T04:35:18',
#   'confidence': 65,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -35.953,
#   'longitude': 141.078,
#   'datetime': '2017-09-27T00:21:05',
#   'confidence': 79,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -35.957,
#   'longitude': 141.088,
#   'datetime': '2017-09-27T00:21:05',
#   'confidence': 79,
#   'date': '27/09/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -37.086999999999996,
#   'longitude': 145.37,
#   'datetime': '2017-09-26T03:52:14',
#   'confidence': 64,
#   'date': '26/09/2017',
#   'surface_temperature_celcius': 33},
#  {'latitude': -37.758,
#   'longitude': 148.721,
#   'datetime': '2017-09-24T15:07:50',
#   'confidence': 76,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.561,
#   'longitude': 148.032,
#   'datetime': '2017-09-24T15:07:49',
#   'confidence': 73,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 34},
#  {'latitude': -37.446,
#   'longitude': 148.102,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.448,
#   'longitude': 148.114,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 72,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 59},
#  {'latitude': -37.453,
#   'longitude': 148.118,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 71,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 34},
#  {'latitude': -37.457,
#   'longitude': 148.143,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 90,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.437,
#   'longitude': 148.10399999999998,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 99,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.434,
#   'longitude': 148.091,
#   'datetime': '2017-09-24T15:07:47',
#   'confidence': 70,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -37.538000000000004,
#   'longitude': 148.895,
#   'datetime': '2017-09-24T15:07:46',
#   'confidence': 74,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.333,
#   'longitude': 148.099,
#   'datetime': '2017-09-24T15:07:45',
#   'confidence': 94,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.33,
#   'longitude': 148.08700000000002,
#   'datetime': '2017-09-24T15:07:45',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.327,
#   'longitude': 148.083,
#   'datetime': '2017-09-24T13:30:10',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -37.375,
#   'longitude': 148.063,
#   'datetime': '2017-09-24T13:30:09',
#   'confidence': 59,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.336,
#   'longitude': 148.07299999999998,
#   'datetime': '2017-09-24T13:30:09',
#   'confidence': 82,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -37.332,
#   'longitude': 148.091,
#   'datetime': '2017-09-24T13:30:09',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -37.363,
#   'longitude': 148.06,
#   'datetime': '2017-09-24T13:30:09',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -37.438,
#   'longitude': 148.09,
#   'datetime': '2017-09-24T13:30:07',
#   'confidence': 84,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.406,
#   'longitude': 148.123,
#   'datetime': '2017-09-24T04:04:19',
#   'confidence': 100,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 88},
#  {'latitude': -37.397,
#   'longitude': 148.121,
#   'datetime': '2017-09-24T04:04:19',
#   'confidence': 58,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -37.452,
#   'longitude': 148.115,
#   'datetime': '2017-09-24T04:04:18',
#   'confidence': 68,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 77},
#  {'latitude': -37.465,
#   'longitude': 148.153,
#   'datetime': '2017-09-24T04:04:18',
#   'confidence': 68,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 63},
#  {'latitude': -37.45,
#   'longitude': 148.126,
#   'datetime': '2017-09-24T04:04:18',
#   'confidence': 64,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 69},
#  {'latitude': -37.436,
#   'longitude': 148.088,
#   'datetime': '2017-09-24T04:04:18',
#   'confidence': 86,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 76},
#  {'latitude': -37.444,
#   'longitude': 148.101,
#   'datetime': '2017-09-24T04:04:18',
#   'confidence': 73,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 66},
#  {'latitude': -37.562,
#   'longitude': 148.05,
#   'datetime': '2017-09-24T04:04:17',
#   'confidence': 61,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 72},
#  {'latitude': -38.5,
#   'longitude': 146.938,
#   'datetime': '2017-09-24T04:04:04',
#   'confidence': 74,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -38.498000000000005,
#   'longitude': 146.95,
#   'datetime': '2017-09-24T04:04:04',
#   'confidence': 84,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -38.495,
#   'longitude': 146.944,
#   'datetime': '2017-09-24T04:04:04',
#   'confidence': 56,
#   'date': '24/09/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -37.497,
#   'longitude': 147.266,
#   'datetime': '2017-09-23T23:50:45',
#   'confidence': 70,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -37.57,
#   'longitude': 148.034,
#   'datetime': '2017-09-23T23:50:44',
#   'confidence': 86,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -37.559,
#   'longitude': 148.037,
#   'datetime': '2017-09-23T23:50:43',
#   'confidence': 56,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.379,
#   'longitude': 148.126,
#   'datetime': '2017-09-23T23:50:40',
#   'confidence': 58,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 82},
#  {'latitude': -37.379,
#   'longitude': 148.132,
#   'datetime': '2017-09-23T23:50:40',
#   'confidence': 62,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 78},
#  {'latitude': -37.434,
#   'longitude': 148.123,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -37.396,
#   'longitude': 148.086,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.406,
#   'longitude': 148.088,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -37.415,
#   'longitude': 148.105,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -37.425,
#   'longitude': 148.107,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.391,
#   'longitude': 148.066,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 75,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -37.399,
#   'longitude': 148.08100000000002,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 84},
#  {'latitude': -37.400999999999996,
#   'longitude': 148.067,
#   'datetime': '2017-09-23T12:47:12',
#   'confidence': 100,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 79},
#  {'latitude': -36.984,
#   'longitude': 148.25,
#   'datetime': '2017-09-23T04:59:18',
#   'confidence': 50,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 35},
#  {'latitude': -37.335,
#   'longitude': 148.064,
#   'datetime': '2017-09-23T04:59:13',
#   'confidence': 88,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -37.347,
#   'longitude': 148.019,
#   'datetime': '2017-09-23T04:59:13',
#   'confidence': 61,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 36},
#  {'latitude': -37.569,
#   'longitude': 148.024,
#   'datetime': '2017-09-23T04:59:11',
#   'confidence': 87,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -37.585,
#   'longitude': 148.032,
#   'datetime': '2017-09-23T04:59:11',
#   'confidence': 80,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -37.586,
#   'longitude': 148.03799999999998,
#   'datetime': '2017-09-23T04:59:10',
#   'confidence': 77,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -36.996,
#   'longitude': 148.22799999999998,
#   'datetime': '2017-09-23T03:21:28',
#   'confidence': 70,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.995,
#   'longitude': 148.268,
#   'datetime': '2017-09-23T03:21:28',
#   'confidence': 56,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -37.554,
#   'longitude': 148.07299999999998,
#   'datetime': '2017-09-23T03:21:19',
#   'confidence': 63,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 37},
#  {'latitude': -37.564,
#   'longitude': 147.99200000000002,
#   'datetime': '2017-09-23T03:21:19',
#   'confidence': 74,
#   'date': '23/09/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.012,
#   'longitude': 141.341,
#   'datetime': '2017-09-22T04:17:10',
#   'confidence': 71,
#   'date': '22/09/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -37.227,
#   'longitude': 142.138,
#   'datetime': '2017-09-21T05:11:47',
#   'confidence': 73,
#   'date': '21/09/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -37.228,
#   'longitude': 142.14600000000002,
#   'datetime': '2017-09-21T05:11:46',
#   'confidence': 76,
#   'date': '21/09/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -37.235,
#   'longitude': 142.153,
#   'datetime': '2017-09-20T04:29:03',
#   'confidence': 78,
#   'date': '20/09/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -37.246,
#   'longitude': 142.143,
#   'datetime': '2017-09-20T04:29:03',
#   'confidence': 89,
#   'date': '20/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -37.236999999999995,
#   'longitude': 142.141,
#   'datetime': '2017-09-20T04:29:03',
#   'confidence': 100,
#   'date': '20/09/2017',
#   'surface_temperature_celcius': 112},
#  {'latitude': -37.238,
#   'longitude': 142.13,
#   'datetime': '2017-09-20T04:29:03',
#   'confidence': 73,
#   'date': '20/09/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -38.001999999999995,
#   'longitude': 144.514,
#   'datetime': '2017-09-20T04:28:45',
#   'confidence': 88,
#   'date': '20/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -34.2695,
#   'longitude': 142.2025,
#   'datetime': '2017-09-10T04:00:00',
#   'confidence': 80,
#   'date': '10/09/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -34.2838,
#   'longitude': 142.204,
#   'datetime': '2017-09-10T03:53:00',
#   'confidence': 84,
#   'date': '10/09/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -34.2803,
#   'longitude': 142.1964,
#   'datetime': '2017-09-10T03:50:30',
#   'confidence': 86,
#   'date': '10/09/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -34.2782,
#   'longitude': 142.2253,
#   'datetime': '2017-09-10T03:50:10',
#   'confidence': 81,
#   'date': '10/09/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -37.4421,
#   'longitude': 148.259,
#   'datetime': '2017-08-14T04:15:40',
#   'confidence': 56,
#   'date': '14/08/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -38.0173,
#   'longitude': 144.0571,
#   'datetime': '2017-08-14T04:11:00',
#   'confidence': 61,
#   'date': '14/08/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.4754,
#   'longitude': 148.161,
#   'datetime': '2017-08-14T04:10:20',
#   'confidence': 67,
#   'date': '14/08/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -37.443000000000005,
#   'longitude': 147.3064,
#   'datetime': '2017-08-14T04:09:30',
#   'confidence': 61,
#   'date': '14/08/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -37.7836,
#   'longitude': 143.9688,
#   'datetime': '2017-08-14T04:07:50',
#   'confidence': 58,
#   'date': '14/08/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -34.848,
#   'longitude': 141.5002,
#   'datetime': '2017-08-13T05:13:30',
#   'confidence': 54,
#   'date': '13/08/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -34.7919,
#   'longitude': 141.6231,
#   'datetime': '2017-08-13T05:08:00',
#   'confidence': 87,
#   'date': '13/08/2017',
#   'surface_temperature_celcius': 62},
#  {'latitude': -34.8421,
#   'longitude': 141.5266,
#   'datetime': '2017-08-13T05:06:10',
#   'confidence': 71,
#   'date': '13/08/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -34.7872,
#   'longitude': 141.6164,
#   'datetime': '2017-08-13T05:05:10',
#   'confidence': 80,
#   'date': '13/08/2017',
#   'surface_temperature_celcius': 53},
#  {'latitude': -34.8425,
#   'longitude': 141.4933,
#   'datetime': '2017-08-13T05:05:00',
#   'confidence': 63,
#   'date': '13/08/2017',
#   'surface_temperature_celcius': 42},
# ...
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 108},
#  {'latitude': -36.8714,
#   'longitude': 142.733,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 77,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -36.7751,
#   'longitude': 145.1696,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 91,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 68},
#  {'latitude': -36.3168,
#   'longitude': 141.1422,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 66,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -36.2394,
#   'longitude': 143.628,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 73,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -36.3278,
#   'longitude': 141.082,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 54,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -36.3961,
#   'longitude': 140.9781,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 91,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 69},
#  {'latitude': -36.3939,
#   'longitude': 140.991,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 66,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -36.7708,
#   'longitude': 145.1908,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 98},
#  {'latitude': -38.4025,
#   'longitude': 146.6501,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 76,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -36.6173,
#   'longitude': 142.1868,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 83,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 56},
#  {'latitude': -37.8701,
#   'longitude': 142.8066,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 78,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.758,
#   'longitude': 143.179,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 98,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 82},
#  {'latitude': -37.7609,
#   'longitude': 143.1633,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 94,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 74},
#  {'latitude': -36.5116,
#   'longitude': 144.562,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 89,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 66},
#  {'latitude': -36.4338,
#   'longitude': 141.1856,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 112},
#  {'latitude': -36.803000000000004,
#   'longitude': 142.9261,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 92,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 70},
#  {'latitude': -37.7505,
#   'longitude': 143.1601,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 78,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -36.5493,
#   'longitude': 144.1879,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 87,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 62},
#  {'latitude': -36.6146,
#   'longitude': 142.2013,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 77,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -36.4399,
#   'longitude': 141.0914,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 59,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.4143,
#   'longitude': 143.27200000000002,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 89,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 65},
#  {'latitude': -37.0434,
#   'longitude': 142.001,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 54,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -36.049,
#   'longitude': 143.175,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 65,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -36.0399,
#   'longitude': 143.6437,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 60,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.7153,
#   'longitude': 143.8226,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 99,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 86},
#  {'latitude': -36.4207,
#   'longitude': 141.6093,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 67,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -36.3295,
#   'longitude': 142.3494,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 84,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -36.8791,
#   'longitude': 142.7261,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 93},
#  {'latitude': -36.7786,
#   'longitude': 145.178,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 105},
#  {'latitude': -36.7038,
#   'longitude': 141.8813,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 70,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -36.7309,
#   'longitude': 142.3633,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 88},
#  {'latitude': -36.882,
#   'longitude': 142.7108,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 92,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 70},
#  {'latitude': -36.3739,
#   'longitude': 141.108,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 78,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 51},
#  {'latitude': -37.6403,
#   'longitude': 142.8696,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 74,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -36.055,
#   'longitude': 144.605,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 54,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -37.6456,
#   'longitude': 142.6646,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 53,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -37.5334,
#   'longitude': 143.0587,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 57,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -36.3462,
#   'longitude': 143.3157,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 73,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -37.5135,
#   'longitude': 142.7238,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 93,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 72},
#  {'latitude': -36.2121,
#   'longitude': 144.6885,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 94,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 74},
#  {'latitude': -36.8237,
#   'longitude': 141.4881,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 84,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 58},
#  {'latitude': -36.8261,
#   'longitude': 141.4747,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 52,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -36.334,
#   'longitude': 144.0309,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 62,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -36.228,
#   'longitude': 144.6721,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 56,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -36.2206,
#   'longitude': 144.6856,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 97,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 80},
#  {'latitude': -36.7904,
#   'longitude': 141.7938,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 74,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -36.788000000000004,
#   'longitude': 141.8077,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 86,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 61},
#  {'latitude': -37.3466,
#   'longitude': 143.123,
#   'datetime': '2017-05-04T04:44:40',
#   'confidence': 66,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 43},
#  {'latitude': -38.4395,
#   'longitude': 146.6166,
#   'datetime': '2017-05-04T00:30:50',
#   'confidence': 77,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -38.0132,
#   'longitude': 146.5269,
#   'datetime': '2017-05-04T00:28:30',
#   'confidence': 88,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 73},
#  {'latitude': -37.6143,
#   'longitude': 142.958,
#   'datetime': '2017-05-04T00:25:30',
#   'confidence': 76,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 49},
#  {'latitude': -38.0148,
#   'longitude': 146.5413,
#   'datetime': '2017-05-04T00:25:30',
#   'confidence': 87,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 71},
#  {'latitude': -37.8412,
#   'longitude': 147.2536,
#   'datetime': '2017-05-04T00:25:10',
#   'confidence': 100,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 87},
#  {'latitude': -37.8429,
#   'longitude': 147.2691,
#   'datetime': '2017-05-04T00:25:00',
#   'confidence': 96,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 78},
#  {'latitude': -37.7177,
#   'longitude': 143.2919,
#   'datetime': '2017-05-04T00:24:50',
#   'confidence': 61,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -38.0233,
#   'longitude': 146.5253,
#   'datetime': '2017-05-04T00:24:50',
#   'confidence': 94,
#   'date': '4/05/2017',
#   'surface_temperature_celcius': 103},
#  {'latitude': -36.5454,
#   'longitude': 144.7402,
#   'datetime': '2017-05-03T04:12:40',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 96},
#  {'latitude': -36.5039,
#   'longitude': 142.8384,
#   'datetime': '2017-05-03T04:09:50',
#   'confidence': 74,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -36.3557,
#   'longitude': 145.5993,
#   'datetime': '2017-05-03T04:09:40',
#   'confidence': 79,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 52},
#  {'latitude': -36.6088,
#   'longitude': 145.2514,
#   'datetime': '2017-05-03T04:09:40',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 115},
#  {'latitude': -36.7593,
#   'longitude': 142.895,
#   'datetime': '2017-05-03T04:09:20',
#   'confidence': 92,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 69},
#  {'latitude': -36.3441,
#   'longitude': 141.5806,
#   'datetime': '2017-05-03T04:08:50',
#   'confidence': 62,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 41},
#  {'latitude': -36.3753,
#   'longitude': 146.6914,
#   'datetime': '2017-05-03T04:08:20',
#   'confidence': 57,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.3051,
#   'longitude': 143.1445,
#   'datetime': '2017-05-03T04:08:20',
#   'confidence': 54,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 39},
#  {'latitude': -36.3851,
#   'longitude': 141.8256,
#   'datetime': '2017-05-03T04:08:10',
#   'confidence': 82,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 55},
#  {'latitude': -36.7597,
#   'longitude': 142.9068,
#   'datetime': '2017-05-03T04:08:10',
#   'confidence': 73,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 48},
#  {'latitude': -35.4603,
#   'longitude': 143.5411,
#   'datetime': '2017-05-03T04:06:40',
#   'confidence': 86,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.7483,
#   'longitude': 142.9052,
#   'datetime': '2017-05-03T04:05:40',
#   'confidence': 76,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 54},
#  {'latitude': -36.0574,
#   'longitude': 141.5856,
#   'datetime': '2017-05-03T04:05:20',
#   'confidence': 84,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 57},
#  {'latitude': -36.1247,
#   'longitude': 145.1437,
#   'datetime': '2017-05-03T04:05:20',
#   'confidence': 71,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -36.3435,
#   'longitude': 141.5513,
#   'datetime': '2017-05-03T04:05:20',
#   'confidence': 90,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 67},
#  {'latitude': -36.6595,
#   'longitude': 143.8887,
#   'datetime': '2017-05-03T04:05:10',
#   'confidence': 72,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -36.0555,
#   'longitude': 141.6071,
#   'datetime': '2017-05-03T04:05:10',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 104},
#  {'latitude': -37.5583,
#   'longitude': 142.9318,
#   'datetime': '2017-05-03T04:03:50',
#   'confidence': 71,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 46},
#  {'latitude': -36.4952,
#   'longitude': 143.971,
#   'datetime': '2017-05-03T04:03:50',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 110},
#  {'latitude': -36.1021,
#   'longitude': 145.7792,
#   'datetime': '2017-05-03T04:03:20',
#   'confidence': 74,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -36.6942,
#   'longitude': 143.8021,
#   'datetime': '2017-05-03T04:03:10',
#   'confidence': 93,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 72},
#  {'latitude': -36.1961,
#   'longitude': 141.6376,
#   'datetime': '2017-05-03T04:03:00',
#   'confidence': 52,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 38},
#  {'latitude': -36.3584,
#   'longitude': 145.9225,
#   'datetime': '2017-05-03T04:03:00',
#   'confidence': 64,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 42},
#  {'latitude': -36.3459,
#   'longitude': 141.5586,
#   'datetime': '2017-05-03T04:03:00',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 91},
#  {'latitude': -36.6072,
#   'longitude': 145.2651,
#   'datetime': '2017-05-03T04:03:00',
#   'confidence': 86,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 60},
#  {'latitude': -36.3526,
#   'longitude': 146.3686,
#   'datetime': '2017-05-03T04:02:50',
#   'confidence': 72,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -36.1603,
#   'longitude': 141.2905,
#   'datetime': '2017-05-03T04:02:40',
#   'confidence': 59,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.1267,
#   'longitude': 147.6711,
#   'datetime': '2017-05-03T04:02:40',
#   'confidence': 68,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.4046,
#   'longitude': 141.1534,
#   'datetime': '2017-05-03T04:02:40',
#   'confidence': 93,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 73},
#  {'latitude': -36.6612,
#   'longitude': 143.8726,
#   'datetime': '2017-05-03T04:02:40',
#   'confidence': 76,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 50},
#  {'latitude': -36.3891,
#   'longitude': 141.0253,
#   'datetime': '2017-05-03T04:02:30',
#   'confidence': 68,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.8763,
#   'longitude': 142.7266,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 68,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -35.4619,
#   'longitude': 143.5251,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 58,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 40},
#  {'latitude': -36.0594,
#   'longitude': 141.5907,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 96,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 79},
#  {'latitude': -36.0576,
#   'longitude': 141.6122,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 100,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 94},
#  {'latitude': -36.1614,
#   'longitude': 141.2978,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 72,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 47},
#  {'latitude': -36.2549,
#   'longitude': 141.9908,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 69,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 44},
#  {'latitude': -36.2531,
#   'longitude': 142.0113,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 70,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 45},
#  {'latitude': -36.1629,
#   'longitude': 143.093,
#   'datetime': '2017-05-03T04:02:20',
#   'confidence': 78,
#   'date': '3/05/2017',
#   'surface_temperature_celcius': 51},
#  ...]

# %%
# importing the MongoClient
from pymongo import MongoClient
#creating the instance of mongoclient
client = MongoClient()
#creating the database called db
db = client.fit5148_assignment_db
#dumping the json in the database
climate_hotspot = json.dumps([row for row in climate_list])
climate_hotspot_json = json.loads(climate_hotspot)

#creating the collection called climate in the database
db.climate.drop()
db.climate.insert_many(climate_hotspot_json)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-63b9156c8149> in <module>
#      10
#      11 #creating the collection called climate in the database
# ---> 12 db.climate.drop()
#      13 db.climate.insert_many(climate_hotspot_json)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in drop(self, session)
#    1097             self.write_concern,
#    1098             self.read_concern)
# -> 1099         dbo.drop_collection(self.__name, session=session)
#    1100
#    1101     def _delete(
#
# ~\Anaconda3\lib\site-packages\pymongo\database.py in drop_collection(self, name_or_collection, session)
#     818         self.__client._purge_index(self.__name, name)
#     819
# --> 820         with self.__client._socket_for_writes() as sock_info:
#     821             return self._command(
#     822                 sock_info, 'drop', value=_unicode(name),
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _socket_for_writes(self)
#    1119
#    1120     def _socket_for_writes(self):
# -> 1121         server = self._get_topology().select_server(writable_server_selector)
#    1122         return self._get_socket(server)
#    1123
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     224         return random.choice(self.select_servers(selector,
#     225                                                  server_selection_timeout,
# --> 226                                                  address))
#     227
#     228     def select_server_by_address(self, address,
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     182         with self._lock:
#     183             server_descriptions = self._select_servers_loop(
# --> 184                 selector, server_timeout, address)
#     185
#     186             return [self.get_server_by_address(sd.address)
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             # came after our most recent apply_selector call, since we've
#     208             # held the lock until now.
# --> 209             self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     210             self._description.check_compatible()
#     211             now = _time()
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
climate_hotspot_json

# %% [markdown]
# ##### Query A.

# %%
db.climate.find_one({'date': '10/12/2017'})

# %% [markdown]
# ##### Query B.

# %%
results = db.hotspot.find({'surface_temperature_celcius': {'$gte': 65, '$lt': 100}}, ['location', 'surface_temperature_celcius', 'confidence'])
for eachResult in results:
    print(eachResult)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-74ff4786994d> in <module>
#       1 results = db.hotspot.find({'surface_temperature_celcius': {'$gte': 65, '$lt': 100}}, ['location', 'surface_temperature_celcius', 'confidence'])
# ----> 2 for eachResult in results:
#       3     print(eachResult)
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1223         if self.__empty:
#    1224             raise StopIteration
# -> 1225         if len(self.__data) or self._refresh():
#    1226             if self.__manipulate:
#    1227                 _db = self.__collection.database
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1115
#    1116         if not self.__session:
# -> 1117             self.__session = self.__collection.database.client._ensure_session()
#    1118
#    1119         if self.__id is None:  # Query
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1596             # Don't make implicit sessions causally consistent. Applications
#    1597             # should always opt-in.
# -> 1598             return self.__start_session(True, causal_consistency=False)
#    1599         except (ConfigurationError, InvalidOperation):
#    1600             # Sessions not supported, or multiple users authenticated.
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1549
#    1550         # Raises ConfigurationError if sessions are not supported.
# -> 1551         server_session = self._get_server_session()
#    1552         opts = client_session.SessionOptions(**kwargs)
#    1553         return client_session.ClientSession(
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1582     def _get_server_session(self):
#    1583         """Internal: start or resume a _ServerSession."""
# -> 1584         return self._topology.get_server_session()
#    1585
#    1586     def _return_server_session(self, server_session, lock):
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     427                             any_server_selector,
#     428                             self._settings.server_selection_timeout,
# --> 429                             None)
#     430                 elif not self._description.readable_servers:
#     431                     self._select_servers_loop(
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             # came after our most recent apply_selector call, since we've
#     208             # held the lock until now.
# --> 209             self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     210             self._description.check_compatible()
#     211             now = _time()
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Query C.

# %%
results = db.climate.find({'date':{'$in':['15/12/2017','16/12/2017']}},{'Hotspot.surface_temperature_celcius':1,"air_temperature_celcius":1,"relative_humidity":1,"max_wind_speed":1,"date":1,"_id":1})

# %%
for eachResult in results:
    pprint(eachResult)
# Out:
# {'Hotspot': [{'surface_temperature_celcius': 42},
#              {'surface_temperature_celcius': 36},
#              {'surface_temperature_celcius': 38},
#              {'surface_temperature_celcius': 40}],
#  '_id': ObjectId('5ce685a293436914c6f7fdfe'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2017',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'Hotspot': [{'surface_temperature_celcius': 43},
#              {'surface_temperature_celcius': 33},
#              {'surface_temperature_celcius': 54},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 75},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 66},
#              {'surface_temperature_celcius': 56},
#              {'surface_temperature_celcius': 60},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 48},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 64},
#              {'surface_temperature_celcius': 57}],
#  '_id': ObjectId('5ce685a293436914c6f7fdff'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2017',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# ##### Query D.

# %%
collection_1= db.climate.aggregate([{"$unwind": "$Hotspot"},
                               {"$match":{"Hotspot.confidence":{"$gt":80,"$lt":100}}},
                               {"$project":{"_id":0,"Hotspot.confidence":1,"Hotspot.surface_temperature_celcius":1,"air_temperature_celcius":1,"Hotspot.datetime":1}}]) 
for i in collection_h:
    print(i)
# Out:
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-06T05:06:30', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 20}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-06T05:06:20', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 20}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-03-07T04:16:10', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-03-09T13:23:40', 'surface_temperature_celcius': 41}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-03-10T04:45:30', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-10T04:45:30', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-10T04:43:50', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-03-12T04:33:50', 'surface_temperature_celcius': 105}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-03-12T04:29:50', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-12T04:27:20', 'surface_temperature_celcius': 98}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-03-14T04:24:40', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-03-14T04:22:20', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-03-14T04:20:50', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-03-14T04:16:30', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-03-14T04:16:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-14T04:14:40', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-03-14T04:14:30', 'surface_temperature_celcius': 79}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-03-14T04:14:30', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 25}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-03-17T04:48:20', 'surface_temperature_celcius': 74}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-03-17T04:45:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-03-17T04:45:00', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-18T03:50:40', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-19T04:39:50', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-03-19T04:39:20', 'surface_temperature_celcius': 79}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-03-19T04:36:00', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-03-19T04:33:00', 'surface_temperature_celcius': 83}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-03-19T04:32:50', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-03-19T04:32:40', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-03-25T03:59:50', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-25T03:58:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-03-25T03:58:10', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-25T03:57:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-03-25T03:57:10', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-26T04:43:20', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-26T04:39:50', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-03-26T04:39:10', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-03-26T04:39:10', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-03-26T04:39:10', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-26T04:39:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-03-26T04:39:10', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-03-28T04:38:00', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-03-28T04:33:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-03-28T04:33:30', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-03-28T04:33:30', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-03-28T04:32:20', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-03-28T04:30:50', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-03-28T04:30:10', 'surface_temperature_celcius': 74}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-03-28T04:30:10', 'surface_temperature_celcius': 82}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-28T04:30:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-28T04:30:10', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-28T04:28:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-03-28T04:28:30', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-28T04:28:30', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-28T04:27:40', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-03-28T04:27:00', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-03-28T04:27:00', 'surface_temperature_celcius': 86}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 81}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 81}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-03-28T04:26:50', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-03-31T05:07:10', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-03-31T05:01:20', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-03-31T04:58:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-03-31T04:57:10', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-03-31T00:36:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-03T13:17:00', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-03T13:15:30', 'surface_temperature_celcius': 40}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-03T13:15:10', 'surface_temperature_celcius': 45}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-03T03:59:10', 'surface_temperature_celcius': 96}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-03T03:57:50', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-03T03:56:20', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-03T03:55:10', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-03T03:55:10', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-03T03:54:00', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-03T03:53:30', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-03T03:52:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-03T03:52:10', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-03T03:52:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-03T03:51:30', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-03T03:51:30', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-03T03:51:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-03T03:51:00', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-03T03:51:00', 'surface_temperature_celcius': 82}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-03T03:50:50', 'surface_temperature_celcius': 97}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-03T03:50:50', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 86}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-03T03:50:40', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-03T01:07:20', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-04T15:31:00', 'surface_temperature_celcius': 44}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-04T04:41:50', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-04T04:41:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-04T04:41:00', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-04T04:41:00', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-04T04:39:50', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-04T04:39:50', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-04T04:39:40', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-04T04:39:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-04T04:37:10', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-04T04:36:10', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-04T04:36:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-04T04:36:00', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-04T04:34:50', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-04T04:34:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-04T04:34:20', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-04T04:34:20', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-04T04:34:00', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-04T04:33:50', 'surface_temperature_celcius': 81}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-04T04:33:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-04T04:33:30', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-04T04:33:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-04T04:33:10', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-04T04:33:00', 'surface_temperature_celcius': 79}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-04T04:33:00', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-04T04:32:50', 'surface_temperature_celcius': 82}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-04T04:32:50', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-04T04:32:50', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-04T04:32:50', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-04T04:32:50', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-04T04:32:40', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-04T04:32:40', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-04T04:32:40', 'surface_temperature_celcius': 92}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-04T04:32:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-05T13:09:00', 'surface_temperature_celcius': 39}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-05T13:08:40', 'surface_temperature_celcius': 44}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-05T13:07:00', 'surface_temperature_celcius': 40}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-05T13:03:00', 'surface_temperature_celcius': 45}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-05T13:03:00', 'surface_temperature_celcius': 39}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-05T13:02:40', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-05T05:16:50', 'surface_temperature_celcius': 88}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-05T05:15:30', 'surface_temperature_celcius': 83}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-05T03:40:50', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-05T03:40:30', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-05T03:40:20', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-05T03:39:30', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-05T03:39:30', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-05T03:39:20', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-05T03:39:20', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-05T03:39:10', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-05T03:39:10', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-05T03:39:10', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-05T03:39:10', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-05T03:39:10', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-06T13:45:30', 'surface_temperature_celcius': 45}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-06T04:32:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-06T04:31:10', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-06T04:27:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-06T04:27:00', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-06T04:27:00', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-06T04:27:00', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-06T04:24:40', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-06T04:24:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-06T04:24:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-06T04:24:00', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-06T04:23:50', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-04-06T04:23:50', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-06T04:23:30', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-06T04:23:10', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-06T04:23:00', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-06T04:22:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-06T04:22:20', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-06T04:22:20', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-06T04:22:20', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-06T04:22:20', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-06T04:22:10', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-06T04:22:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-06T04:22:10', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-06T04:21:30', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-06T04:21:10', 'surface_temperature_celcius': 96}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-06T04:21:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-06T04:20:50', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-06T04:20:50', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 81}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 104}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 86}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-06T04:20:40', 'surface_temperature_celcius': 89}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-07T12:56:50', 'surface_temperature_celcius': 41}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-07T12:56:30', 'surface_temperature_celcius': 49}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-07T12:53:40', 'surface_temperature_celcius': 41}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-07T12:52:10', 'surface_temperature_celcius': 41}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-07T12:51:20', 'surface_temperature_celcius': 45}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-07T12:50:50', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-07T12:50:40', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-07T05:03:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-07T03:28:20', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-07T03:27:30', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-07T03:27:20', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-07T03:27:20', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 21}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-04-08T04:14:00', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-08T04:12:50', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-08T04:08:50', 'surface_temperature_celcius': 83}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-08T04:08:30', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-11T04:39:20', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-11T04:39:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-11T04:39:00', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-12T13:15:10', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-12T05:28:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-12T05:21:40', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-12T03:54:10', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-12T03:50:00', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-12T03:50:00', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-12T03:50:00', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-12T03:47:50', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-12T03:47:50', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-12T03:47:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-12T03:47:20', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-12T03:47:20', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-12T03:45:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-12T03:44:40', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-12T03:44:40', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-12T03:44:40', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-12T03:44:40', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-04-13T04:38:00', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-13T04:38:00', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:36:50', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:36:30', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:36:20', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:35:40', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:35:40', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:35:30', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:34:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-13T04:34:20', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:33:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:33:40', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:33:30', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-04-13T04:33:30', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:33:30', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:33:20', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:33:10', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:33:00', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-13T04:33:00', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-13T04:31:00', 'surface_temperature_celcius': 82}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:30:50', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:30:50', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:30:10', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:30:00', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:29:50', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:29:40', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:29:40', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:28:50', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:28:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:28:20', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:28:20', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 72}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:28:10', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-04-13T04:27:40', 'surface_temperature_celcius': 82}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:27:40', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:27:30', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:27:20', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-13T04:26:50', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:50', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:50', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:26:50', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:26:40', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 79}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 71}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 81}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 16}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-04-13T04:26:30', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 16}
# ...
# {'Hotspot': {'confidence': 91, 'datetime': '2017-06-04T04:08:10', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 9}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-06-04T04:02:10', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 9}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-06-04T04:02:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 9}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-06-07T04:35:50', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-06-07T04:33:50', 'surface_temperature_celcius': 78}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-06-07T04:32:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-06-07T04:32:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-06-07T04:32:10', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-06-07T04:32:10', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 8}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-06-09T04:23:20', 'surface_temperature_celcius': 52}, 'air_temperature_celcius': 10}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-06-09T04:23:16', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 10}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-06-14T04:43:00', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-06-20T04:02:00', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-06-20T04:02:00', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-06-30T00:27:19', 'surface_temperature_celcius': 48}, 'air_temperature_celcius': 5}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-06-30T00:27:19', 'surface_temperature_celcius': 48}, 'air_temperature_celcius': 5}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-07-02T04:29:18', 'surface_temperature_celcius': 52}, 'air_temperature_celcius': 6}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-07-02T04:29:18', 'surface_temperature_celcius': 52}, 'air_temperature_celcius': 6}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-07-02T04:29:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 6}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-07-02T04:29:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 6}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-07-06T04:08:00', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 9}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-07-06T04:02:00', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 9}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-07-31T13:21:00', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 7}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-08-01T00:20:30', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 7}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-08-02T03:45:40', 'surface_temperature_celcius': 87}, 'air_temperature_celcius': 5}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-08-13T05:08:00', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-08-13T05:02:30', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-09-10T03:53:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-09-10T03:50:30', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-09-10T03:50:10', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-09-20T04:29:03', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-09-20T04:28:45', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-09-23T23:50:44', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-09-23T04:59:13', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-09-23T04:59:11', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-09-24T15:07:47', 'surface_temperature_celcius': 41}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-09-24T15:07:47', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-09-24T15:07:45', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-09-24T13:30:09', 'surface_temperature_celcius': 38}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-09-24T13:30:07', 'surface_temperature_celcius': 50}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-09-24T04:04:18', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-09-24T04:04:04', 'surface_temperature_celcius': 52}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-09-27T04:35:36', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-09-27T04:35:36', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-09-29T04:22:31', 'surface_temperature_celcius': 49}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-10-01T04:10:28', 'surface_temperature_celcius': 52}, 'air_temperature_celcius': 12}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-10-01T04:10:28', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 12}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-10-02T04:53:10', 'surface_temperature_celcius': 50}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-10-02T04:53:09', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 11}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-10-03T13:23:43', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-10-03T03:58:15', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-10-03T03:58:15', 'surface_temperature_celcius': 48}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-10-03T03:58:15', 'surface_temperature_celcius': 49}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-10-03T03:58:15', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-10-03T03:58:15', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-10-03T03:58:14', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-10-03T03:58:14', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-10-04T04:41:00', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-10-04T04:41:00', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 19}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-10-07T12:59:33', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-10-10T04:04:19', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-10-15T04:23:01', 'surface_temperature_celcius': 85}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-10-17T13:36:12', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 22}
# {'Hotspot': {'confidence': 91, 'datetime': '2017-10-17T04:10:45', 'surface_temperature_celcius': 68}, 'air_temperature_celcius': 22}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-10-17T04:10:32', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 22}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-10-18T00:39:02', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-10-18T00:39:02', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-10-20T04:41:19', 'surface_temperature_celcius': 50}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-10-21T01:09:55', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 12}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-10-21T01:09:54', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 12}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-10-27T04:47:31', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 22}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-10-28T03:52:17', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 15}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-11-05T04:41:34', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-11-05T04:41:19', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-11-05T04:41:19', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 13}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-11-09T04:16:48', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 96, 'datetime': '2017-11-09T04:16:48', 'surface_temperature_celcius': 77}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-11-09T04:16:44', 'surface_temperature_celcius': 62}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-11-09T04:16:44', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 14}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-11-11T04:04:25', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 89, 'datetime': '2017-11-12T00:33:15', 'surface_temperature_celcius': 69}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-11-13T03:52:15', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-11-13T03:52:14', 'surface_temperature_celcius': 53}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-11-14T04:35:04', 'surface_temperature_celcius': 65}, 'air_temperature_celcius': 28}
# {'Hotspot': {'confidence': 85, 'datetime': '2017-11-21T00:27:21', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-11-22T03:46:00', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 88, 'datetime': '2017-11-22T03:46:00', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 23}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-11-23T04:28:59', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-11-23T04:28:59', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 24}
# {'Hotspot': {'confidence': 97, 'datetime': '2017-11-29T03:52:10', 'surface_temperature_celcius': 80}, 'air_temperature_celcius': 28}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-11-29T03:52:10', 'surface_temperature_celcius': 84}, 'air_temperature_celcius': 28}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-11-30T12:22:15', 'surface_temperature_celcius': 38}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-11-30T12:22:15', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-11-30T04:35:00', 'surface_temperature_celcius': 59}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 98, 'datetime': '2017-11-30T04:34:57', 'surface_temperature_celcius': 83}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-11-30T04:34:57', 'surface_temperature_celcius': 57}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-11-30T04:34:57', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 99, 'datetime': '2017-11-30T04:34:57', 'surface_temperature_celcius': 86}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-11-30T00:20:53', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-11-30T00:20:53', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-11-30T00:20:53', 'surface_temperature_celcius': 76}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-11-30T00:20:53', 'surface_temperature_celcius': 56}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-11-30T00:20:53', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 26}
# {'Hotspot': {'confidence': 87, 'datetime': '2017-12-09T00:14:34', 'surface_temperature_celcius': 61}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 81, 'datetime': '2017-12-09T00:14:34', 'surface_temperature_celcius': 54}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-12-09T00:14:33', 'surface_temperature_celcius': 58}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-12-09T00:14:33', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 83, 'datetime': '2017-12-13T04:04:19', 'surface_temperature_celcius': 60}, 'air_temperature_celcius': 28}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-12-14T04:47:25', 'surface_temperature_celcius': 70}, 'air_temperature_celcius': 17}
# {'Hotspot': {'confidence': 92, 'datetime': '2017-12-15T13:17:17', 'surface_temperature_celcius': 42}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 94, 'datetime': '2017-12-16T15:38:39', 'surface_temperature_celcius': 43}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-12-16T04:35:13', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 84, 'datetime': '2017-12-16T04:34:58', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 95, 'datetime': '2017-12-16T04:34:58', 'surface_temperature_celcius': 75}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 90, 'datetime': '2017-12-16T04:34:57', 'surface_temperature_celcius': 66}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 93, 'datetime': '2017-12-16T00:21:12', 'surface_temperature_celcius': 73}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-12-16T00:21:11', 'surface_temperature_celcius': 55}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-12-16T00:20:53', 'surface_temperature_celcius': 64}, 'air_temperature_celcius': 18}
# {'Hotspot': {'confidence': 82, 'datetime': '2017-12-27T00:02:15', 'surface_temperature_celcius': 63}, 'air_temperature_celcius': 28}
# {'Hotspot': {'confidence': 86, 'datetime': '2017-12-27T00:02:14', 'surface_temperature_celcius': 67}, 'air_temperature_celcius': 28}

# %% [markdown]
# ##### Query E.

# %%
collection_2=db.climate.aggregate([{"$unwind":"$Hotspot"},{"$sort":{"Hotspot.surface_temperature_celcius":-1}},{"$limit":10}])
for i in collection_2:
    pprint(i)
# Out:
# {'Hotspot': {'confidence': 100,
#              'date': '18/04/2017',
#              'datetime': '2017-04-18T04:52:00',
#              'location': [-38.1665, 143.062],
#              'surface_temperature_celcius': 124},
#  '_id': ObjectId('5ce685a293436914c6f7fd0d'),
#  'air_temperature_celcius': 15,
#  'date': '18/04/2017',
#  'max_wind_speed': 9.9,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'Hotspot': {'confidence': 100,
#              'date': '4/04/2017',
#              'datetime': '2017-04-04T04:32:50',
#              'location': [-36.343, 142.1986],
#              'surface_temperature_celcius': 123},
#  '_id': ObjectId('5ce685a293436914c6f7fcff'),
#  'air_temperature_celcius': 16,
#  'date': '4/04/2017',
#  'max_wind_speed': 12.0,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'Hotspot': {'confidence': 100,
#              'date': '1/05/2017',
#              'datetime': '2017-05-01T04:14:20',
#              'location': [-36.9318, 143.0907],
#              'surface_temperature_celcius': 122},
#  '_id': ObjectId('5ce685a293436914c6f7fd1a'),
#  'air_temperature_celcius': 14,
#  'date': '1/05/2017',
#  'max_wind_speed': 20.0,
#  'precipitation': ' 0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'Hotspot': {'confidence': 100,
#              'date': '18/03/2017',
#              'datetime': '2017-03-18T03:50:50',
#              'location': [-37.016999999999996, 148.1297],
#              'surface_temperature_celcius': 121},
#  '_id': ObjectId('5ce685a293436914c6f7fcee'),
#  'air_temperature_celcius': 21,
#  'date': '18/03/2017',
#  'max_wind_speed': 11.1,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'Hotspot': {'confidence': 100,
#              'date': '4/04/2017',
#              'datetime': '2017-04-04T04:32:40',
#              'location': [-36.3521, 142.2008],
#              'surface_temperature_celcius': 120},
#  '_id': ObjectId('5ce685a293436914c6f7fcff'),
#  'air_temperature_celcius': 16,
#  'date': '4/04/2017',
#  'max_wind_speed': 12.0,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'Hotspot': {'confidence': 100,
#              'date': '13/04/2017',
#              'datetime': '2017-04-13T04:28:10',
#              'location': [-37.0745, 141.0692],
#              'surface_temperature_celcius': 120},
#  '_id': ObjectId('5ce685a293436914c6f7fd08'),
#  'air_temperature_celcius': 16,
#  'date': '13/04/2017',
#  'max_wind_speed': 9.9,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'Hotspot': {'confidence': 100,
#              'date': '13/05/2017',
#              'datetime': '2017-05-13T04:40:20',
#              'location': [-34.9938, 141.876],
#              'surface_temperature_celcius': 120},
#  '_id': ObjectId('5ce685a293436914c6f7fd26'),
#  'air_temperature_celcius': 9,
#  'date': '13/05/2017',
#  'max_wind_speed': 8.0,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'Hotspot': {'confidence': 100,
#              'date': '18/04/2017',
#              'datetime': '2017-04-18T04:44:50',
#              'location': [-37.8326, 143.4999],
#              'surface_temperature_celcius': 120},
#  '_id': ObjectId('5ce685a293436914c6f7fd0d'),
#  'air_temperature_celcius': 15,
#  'date': '18/04/2017',
#  'max_wind_speed': 9.9,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'Hotspot': {'confidence': 100,
#              'date': '4/04/2017',
#              'datetime': '2017-04-04T04:40:00',
#              'location': [-36.1057, 141.7608],
#              'surface_temperature_celcius': 120},
#  '_id': ObjectId('5ce685a293436914c6f7fcff'),
#  'air_temperature_celcius': 16,
#  'date': '4/04/2017',
#  'max_wind_speed': 12.0,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'Hotspot': {'confidence': 100,
#              'date': '4/05/2017',
#              'datetime': '2017-05-04T04:44:50',
#              'location': [-36.4057, 140.9806],
#              'surface_temperature_celcius': 119},
#  '_id': ObjectId('5ce685a293436914c6f7fd1d'),
#  'air_temperature_celcius': 10,
#  'date': '4/05/2017',
#  'max_wind_speed': 7.0,
#  'precipitation': ' 0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# ##### Query E.

# %%
collection_3=db.climate.aggregate([{"$unwind":"$Hotspot"},
                                  {"$group":{"_id":{"datetime":"$datetime","date":"$date","_id":"$_id"},
                                            "count":{"$sum":1}}},
                                  {"$project":{"date":1,"count":1,"_id":0}}])

# %% [markdown]
# ##### Query F.

# %%
collection_4=db.climate.aggregate([{ "$match": {"Hotspot": {"$exists": True, "$ne":[]}}},
                                   {"$project":{"_id":0,"date": 1,
                                                "TotalNo_of_fires":{"$size":"$Hotspot"}}}])

# %% [markdown]
# ##### Query G.

# %%
collection_5=db.climate.aggregate([{"$match": {"Hotspot":{"$exists": True,"$ne":[]}}},
                                  {"$project":{"_id":0,"date":1, "avg":{"$avg":"$Hotspot.surface_temperature_celcius"}}}])
